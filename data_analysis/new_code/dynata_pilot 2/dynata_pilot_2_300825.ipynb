# %%
import pandas as pd
import numpy as np
import scipy as sp

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import mpl_toolkits as mplot3d

import statsmodels.api as sm
from statsmodels.miscmodels.ordinal_model import OrderedModel
from scipy.stats.mstats import winsorize


pd.set_option("display.max_columns", None)
pd.reset_option("display.max_rows")
pd.set_option('future.no_silent_downcasting', True)

from utils.categorical_qcut import categorical_qcut

from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# # Data Scoring

# %%
scenarios_answers_dict = {
    'M25-1': 'Try calling a close friend or hostel mate for immediate help, and together ensure he gets urgent medical care.',
    'M25-2': 'Use allergy medication if available and call for emergency help.',
    'M25-3': 'Call for the emergency',
    'M25-4': 'Clean the wound carefully, press to control the bleeding, cover it, and arrange to see a doctor right away.',
    'M25-5': 'Stop, sit upright, slow his breathing, and ask for help.',
    'M25-6': 'Try calling or messaging the bank’s helpline right away to report the situation and at the same time use the app to freeze or block his card if possible.',
    'M25-7': 'Hang up the call without giving any information, then look up and contact the official police station independently to check if the demand was real.',
    'M25-8': 'Call the bank directly using a number on their official website and ask if the loan email is genuine, without clicking the link.',
    'M25-9': 'Research the scheme independently using RBI or SEBI advisories.',
    'M25-10': 'Check his payment/card records separately and contact his provider if needed.',
    'M25-11': 'Ignore the link, verify status in-app, and enable security features.',
    'M25-12': 'Block UPI and logout from accounts immediately.',
    'M25-13': 'Refuse the caller, then disconnect and reach out to the bank based on the phone number on the debit card.',
    'M25-14': 'Change the account password, look through security settings, and enable additional protection like two factor login.',
    'M25-15': 'Save evidence, secure all accounts, seek support, and prepare a report.',
    'M25-16': 'Take screenshots of the posts and messages, and then reach out to a trusted authority figure or counsellor who can step in to support him.',
    'M25-17': 'Confront the friend calmly to clear things up, and if it keeps happening, get hostel staff involved.',
    'M25-18': 'Firmly refuse and step away from the situation if necessary, seeking help if required.',
    'M25-19': 'Keep the messages as evidence and reach out to a student helpline or official channel, even if he’s nervous.',
    'M25-20': 'Talk honestly about his feelings with a supportive friend, mentor, or counselor.',
    
    
    'M59-1': 'Take an aspirin to reduce the risk of heart trouble, then call emergency services.',
    'M59-2': 'Use the allergy medicine he carries with him—like an antihistamine—and at the same time ask someone nearby to get emergency help.',
    'M59-3': 'Grab his phone and dial emergency services straight away, telling them what’s happening even if his words come out unclear, and stay put until help arrives.',
    'M59-4': 'Quickly grab a cloth or towel to press firmly on the wound, raise his hand higher to slow the bleeding, and call for urgent help.',
    'M59-5': 'Sit down if possible, mention to someone nearby that he’s feeling unwell, and ask for anything sweet or sugary he can have while he waits for help.',

    'M59-6': 'Use his banking app or the helpline to stop further transactions right away and then check what else needs to be reported.',
    'M59-7': 'Hang up and independently verify via government channels.',
    'M59-8': 'Check his credit report with an official bureau and contact the bank.',
    'M59-9': 'Take some time to find out more about the start-up on his own, checking what’s publicly available, before choosing whether to invest.',
    'M59-10': 'Check his KYC status using the bank’s app or by logging in the usual way, without using the link in the email.',
    
    'M59-11': "Open his bank’s app or log in through his usual method to see if there are any actual alerts about his account, rather than using the link in the message.",
    'M59-12': 'Go into his account settings to change his password, add two-factor authentication, and make sure nobody else can access his email.',
    'M59-13': 'Tell the caller he’ll think about it and first check with his bank the usual way, instead of installing anything right away.',
    'M59-14': 'Regain access through the account recovery process and inform contacts.',
    'M59-15': 'Save any evidence of what happened, review and tighten the security on his accounts, and look for help reporting the breach.',
    
    'M59-16': 'Arrange to talk privately with his supervisor or someone in HR, and respectfully ask about the changes and exclusions to understand what’s behind them.',
    'M59-17': 'Save the posts and reach out to a society committee member for help.',
    'M59-18': 'Contact a trusted friend or relative and explore together possible ways to reconnect.',
    'M59-19': 'Clearly state his limitations and seek shared responsibility from family members.',
    'M59-20': 'Approach his friend in a kind and genuine manner to ask about the situation.',

    
    'M60-1': 'Take aspirin and seek help immediately.',
    'M60-2': 'Take his allergy medicine if he has it, and ask someone nearby to get urgent medical help instead of waiting to see if it improves.',
    'M60-3': 'Try to call for medical help right away and explain what’s happening as best he can, rather than waiting alone.',
    'M60-4': 'Apply pressure and elevate the hand, then get help.',
    'M60-5': 'Sit down right away, ask someone nearby if they have anything sweet he can eat, and mention that he’s not feeling well so he can get help if needed.',

    'M60-6': 'Call his bank’s helpline right away to talk about what’s happening and find out how to stop further transactions.',
    'M60-7': 'Hang up and call the Income Tax Department on the number he normally uses, just to make sure the request from the caller is actually genuine.',
    'M60-8': 'Contact the concerned bank and credit bureau to report the issue.',
    'M60-9': 'Decline and independently research the investment scheme.',
    'M60-10': 'Get in touch with his bank using the official website or stop by in person to ask if the alert is genuine before taking any action.',

    'M60-11': 'Log in using the bank’s app he usually uses, or wait to ask someone at his branch about the alert.',
    'M60-12': 'Change his password and set up two-factor authentication.',
    'M60-13': 'Refuse, disconnect, and verify with his bank directly.',
    'M60-14': 'Try to recover his account using the recovery process, and let his contacts know so they’re aware something unusual is happening.',
    'M60-15': 'Gather any evidence of what’s happened, review the security of his accounts, and ask someone he trusts to help him report what’s going on.',

    'M60-16': 'Contact a trusted friend or community group to reconnect socially.',
    'M60-17': 'Speak one-on-one with a trusted neighbor or a society official to get their honest perspective and, if needed, clear up any misunderstandings in private.',
    'M60-18': 'Open a conversation with a family member he trusts to seek understanding and resolution.',
    'M60-19': "Tell his family honestly that he needs help and identify specific support he’d appreciate.",
    'M60-20': 'Ask a friendly neighbor in a polite, non-confrontational way if he missed an invite.',


    'W25-1': 'Call for help from hostel staff or friends, and get to a campus clinic or similar immediately.',
    'W25-2': 'Use her allergy medication (if available) and seek emergency help immediately.',
    'W25-3': 'Call for the emergency',
    'W25-4': 'Clean the wound, press to stop the bleeding, and get someone to take her to a clinic.',
    'W25-5': 'Sit down and focus on slowing her breathing, then look for a way to get help, rather than continuing her run.',

    'W25-6': 'Use her banking app or call the helpline right away to block her card and inform the bank about what’s happened.',
    'W25-7': 'Hang up, then verify the demand with official government contacts.',
    'W25-8': 'Contact her bank and the credit bureau as soon as possible to report the problem and ask what steps she should take.',
    'W25-9': 'Look up details about the scheme using official sites or check what financial regulators say before deciding what to do next.',
    'W25-10': 'Do not open the PDF; verify independently using her bank app or statement.',

    'W25-11': "Skip clicking the link, open her Instagram app directly to check for any issues, and consider updating her account’s security settings.",
    'W25-12': 'Use her banking app to block UPI transactions right away and let her bank know what’s happened.',
    'W25-13': 'Say no to sharing her OTP, end the call, and check with the actual wallet app’s helpline to see if there really is a problem.',
    'W25-14': 'Go into her email account, update her password and add some extra security options.',
    'W25-15': 'Save evidence and alert someone she trusts while preparing to report.',

    'W25-16': "Save screenshots as evidence and approach a counselor or a trusted adult for help.",
    'W25-17': 'Have a calm one-on-one conversation with her roommate or talk to the hostel warden.',
    'W25-18': 'Say clearly that she doesn’t want to drink and, if things feel too uncomfortable, move away from the group for a bit.',
    'W25-19': 'Keep the messages as evidence and reach out to the student support office or someone at the university who can help.',
    'W25-20': 'Speak with a counselor or someone she trusts about feeling left out and work through her emotions.',




    'W59-1': 'Take an aspirin if it’s available, call for help, and let someone know about her symptoms.',
    'W59-2': 'Take her allergy medicine if she has it, and get someone to call for medical help right away.',
    'W59-3': 'Call emergency medical services at once.',
    'W59-4': 'Apply direct pressure, elevate hand and call for help.',
    'W59-5': 'Sit down, ask someone nearby for something sweet, and let them know she’s not feeling well.',

    'W59-6': 'Use her bank’s app or call to block the card as soon as possible and tell the bank about the charges.',
    'W59-7': 'Hang up and independently contact the Income Tax Department.',
    'W59-8': 'Check her credit report through official channels and alert her bank.',
    'W59-9': 'Look up information about the scheme herself and see what she can find from reliable sites before making a decision.',
    'W59-10': 'Use her bank’s app or visit the branch to see if her KYC is actually pending before responding to the email.',
    
    'W59-11': 'Skip the link and log in with her usual banking app or website to check if there’s a real issue.',
    'W59-12': 'Change her password and turn on two-factor authentication.',
    'W59-13': 'Refuse and verify with official IT support.',
    'W59-14': 'Change her password and secure her account.',
    'W59-15': 'Save evidence, secure accounts, and reach out for support while reporting.',

    'W59-16': 'Reach out directly to her supervisor or HR to discuss her concerns.',
    'W59-17': 'Save the hurtful messages as evidence and request intervention from building management.',
    'W59-18': 'Reach out to a trusted friend or counselor and share her feelings honestly.',
    'W59-19': 'Talk honestly and respectfully with her in-laws about boundaries and shared responsibilities.',
    'W59-20': 'Privately and calmly seek clarification, possibly requesting mediation.',


    'W60-1': 'Take an aspirin if she has one, call for help straight away, and let someone know what she’s feeling.',
    'W60-2': 'Stay still and shout for assistance.',
    'W60-3': 'Stop reading, call for help, and get to the hospital.',
    'W60-4': 'Move to a safe spot, let a nearby neighbor know she’s confused, and ask for help getting checked by a doctor.',
    'W60-5': 'Pause before taking the pills, call the pharmacy to explain what she’s noticed, and ask if there’s been any change to her prescription.',

    'W60-6': 'Call the bank’s customer service line right away to report the missing money and freeze her account.',
    'W60-7': 'Hang up, then call her bank using the number listed on her bank documents.',
    'W60-8': 'Contact her bank or credit service to ask about placing a fraud alert on her credit profile.',
    'W60-9': 'Decide to find out more about the chit fund through independent sources before making any choice.',
    'W60-10': 'Check her fixed deposit status by logging into her usual banking app or visiting her bank.',

    'W60-11': 'Verify with someone she trusts and ignore the suspicious message.',
    'W60-12': 'Ask a trusted family member or neighbor for help reading the instructions.',
    'W60-13': 'Refuse and independently verify with someone she knows.',
    'W60-14': 'Set the phone to airplane mode and seek help to check for malware or unwanted apps.',
    'W60-15': 'Change her password and secure the account.',
    
    'W60-16': 'Reach out to someone she trusts and share how she’s feeling.',
    'W60-17': 'Talk privately with someone she trusts in the group to clear things up or address what she’s heard.',
    'W60-18': 'Reflect for a while and then gently bring up her feelings with a family member.',
    'W60-19': 'Let her family know about her concerns and clearly request specific help where needed.',
    'W60-20': 'Gently ask a trusted neighbor if there was a reason she was left out.',


}

# %% [markdown]
# # Data Cleaning

# %%
# importing
import_path = f"../../data_cleaned/india/dynata_pilot 2/"
data = pd.read_csv(f"{import_path}/DynataScenarioPiloting_August 29.csv")

questions_df = data[:1]

data = data[2:].copy()

# removing samples from pilot 1
data["StartDate"] = pd.to_datetime(data["StartDate"], format = "%Y-%m-%d %H:%M:%S")
data = data.loc[data["StartDate"] >= "2025-08-27"].copy().reset_index(drop = True)

data["Q2"] = data["Q2"].astype(float)
raw_data = data.copy()

# scoring
print("Following questions have no correct answers in the demographic:")
for key, value in scenarios_answers_dict.items():
    data[key] = np.where(data[key].str.strip() == value.strip(), 1,
                         np.where(pd.isna(data[key].str.strip()), np.nan, 0
                                  )
                        )
    if data[key].sum() == 0:
        print(f"{key}: sum = {data[key].sum()}, count = {data[key].count()}")

# removing those that were filtered out due to demographic misalignment
data = data.copy()
data["score_sum"] = data.loc[:, list(scenarios_answers_dict.keys())].sum(axis = 1)
data = data.loc[ data["score_sum"]!= 0].copy()

# Removing preview responses
data = data.loc[ data["Status"] != "Survey Preview"].copy()

# <0.5 median time of completion filtered --> already done for this dataset
data["Duration (in seconds)"] = data["Duration (in seconds)"].astype("Int64")
median = data["Duration (in seconds)"].astype("Int64").median()
data = data.loc[ data["Duration (in seconds)"] >= median*0.5].copy()
print("\nPost removing <0.5 median time responses:", len(data["ResponseId"]))

output_col = ["ResponseId", "Q1", "Q2", "Q3", "Q4a"] + list(scenarios_answers_dict.keys())
output = data.loc[:, output_col].copy()
output.to_excel("dynata_pilot_2_cleaned_300825.xlsx")
# Out:
# Following questions have no correct answers in the demographic:
#
# Post removing <0.5 median time responses: 144

# %%
scenarios_questions_dict = {}
for key in scenarios_answers_dict.keys():
    scenarios_questions_dict[key] = questions_df[key][0]

# %%
def sample_prep(data, sex, age):
    sex2 = "Male" if sex == "M" else "Female"
    if age == 25:
        age_upper = 25
        age_lower = 18
    elif age == 59:
        age_upper = 59
        age_lower = 26
    else:
        age_upper = 122
        age_lower = 60
        
    sample = data.dropna(subset = ["Q1", "Q2"]).loc[ (data["Q1"] == sex2) & ((data["Q2"] >= age_lower) & (data["Q2"] <= age_upper))].copy()
    return sample

def question_analysis(data, sex, age):

    output_list = []
    sample = sample_prep(data, sex, age)
    if sex not in {"M", "W"}:
        raise ValueError("sex not applicable, input one of 'M' or 'W'")
    if age not in {25, 59, 60}:
        raise ValueError("age not applicable, input one of 25, 59, 60")

    col_prefix = f"{sex}{age}-"
    focal_columns = [x for x in sample.columns if x.startswith(col_prefix)]
    
    for col in focal_columns:
        print(f"{col}:{ sample[col].sum() / sample[col].count() }")
        output_list.append(sample[col].sum() / sample[col].count())
    
    return output_list

# %%
# Demographics
for sex in ["M", "W"]:
    for age in [25, 59, 60]:
        sex2 = "Male" if sex == "M" else "Female"
        if age == 25:
            age2 = "18-25"
        elif age == 59:
            age2 = "26-59"
        else:
            age2 = "60+"

        print(f"{sex2:<7} {age2:<7}: {len(sample_prep(data, sex, age))}")
# Out:
# Male    18-25  : 23
# Male    26-59  : 27
# Male    60+    : 25
# Female  18-25  : 26
# Female  26-59  : 23
# Female  60+    : 20

# %% [markdown]
# # Score Averages for each demoghraphic

# %%
avg_scores_list = []

for sex in ["M", "W"]:
    for age in [25, 59, 60]:
        sex2 = "Male" if sex == "M" else "Female"
        if age == 25:
            age2 = "18-25"
        elif age == 59:
            age2 = "26-59"
        else:
            age2 = "60+"

        print(f"\n\n{sex2:<7} {age2:<7}: count: {len(sample_prep(data, sex, age))}")
        avg_scores_list.append(question_analysis(data, sex, age))

avg_scores_list = np.array(avg_scores_list).flatten()
# Out:
# Male    18-25  : count: 23
# M25-1:0.6666666666666666
# M25-2:1.0
# M25-3:0.5
# M25-4:0.8095238095238095
# M25-5:0.95
# M25-6:0.7727272727272727
# M25-7:0.9130434782608695
# M25-8:0.65
# M25-9:0.65
# M25-10:0.5714285714285714
# M25-11:0.7619047619047619
# M25-12:0.4090909090909091
# M25-13:0.5238095238095238
# M25-14:0.8
# M25-15:0.6190476190476191
# M25-16:0.7619047619047619
# M25-17:0.6666666666666666
# M25-18:0.47619047619047616
# M25-19:0.6666666666666666
# M25-20:0.7
#
#
# Male    26-59  : count: 27
# M59-1:0.7916666666666666
# M59-2:0.84
# M59-3:0.7692307692307693
# M59-4:0.6956521739130435
# M59-5:0.8076923076923077
# M59-6:0.9130434782608695
# M59-7:0.6086956521739131
# M59-8:0.7307692307692307
# M59-9:0.68
# M59-10:0.8260869565217391
# M59-11:0.88
# M59-12:0.8846153846153846
# M59-13:0.625
# M59-14:0.4230769230769231
# M59-15:0.7307692307692307
# M59-16:0.75
# M59-17:0.5833333333333334
# M59-18:0.6
# M59-19:0.52
# M59-20:0.6538461538461539
#
#
# Male    60+    : count: 25
# M60-1:0.9565217391304348
# M60-2:0.9166666666666666
# M60-3:0.7727272727272727
# M60-4:0.782608695652174
# M60-5:1.0
# M60-6:1.0
# M60-7:0.75
# M60-8:0.875
# M60-9:0.782608695652174
# M60-10:0.8333333333333334
# M60-11:0.7391304347826086
# M60-12:0.9090909090909091
# M60-13:0.782608695652174
# M60-14:0.7916666666666666
# M60-15:0.6363636363636364
# M60-16:0.4782608695652174
# M60-17:0.64
# M60-18:0.6956521739130435
# M60-19:0.8636363636363636
# M60-20:0.6666666666666666
#
#
# Female  18-25  : count: 26
# W25-1:0.6923076923076923
# W25-2:0.56
# W25-3:0.56
# W25-4:0.7916666666666666
# W25-5:0.76
# W25-6:0.75
# W25-7:0.9130434782608695
# W25-8:0.92
# W25-9:0.7916666666666666
# W25-10:0.88
# W25-11:0.72
# W25-12:0.84
# W25-13:1.0
# W25-14:0.7391304347826086
# W25-15:0.8333333333333334
# W25-16:0.92
# W25-17:0.875
# W25-18:0.8636363636363636
# W25-19:0.8461538461538461
# W25-20:0.5909090909090909
#
#
# Female  26-59  : count: 23
# W59-1:0.7727272727272727
# W59-2:0.8095238095238095
# W59-3:0.9090909090909091
# W59-4:0.5909090909090909
# W59-5:0.6818181818181818
# W59-6:0.7619047619047619
# W59-7:0.5217391304347826
# W59-8:0.5
# W59-9:0.6666666666666666
# W59-10:0.7727272727272727
# W59-11:0.6666666666666666
# W59-12:0.6818181818181818
# W59-13:0.5714285714285714
# W59-14:0.782608695652174
# W59-15:0.8571428571428571
# W59-16:0.6666666666666666
# W59-17:0.5714285714285714
# W59-18:0.7142857142857143
# W59-19:0.7142857142857143
# W59-20:0.19047619047619047
#
#
# Female  60+    : count: 20
# W60-1:0.8
# W60-2:0.7
# W60-3:0.9
# W60-4:0.8
# W60-5:0.85
# W60-6:0.9
# W60-7:0.7
# W60-8:0.85
# W60-9:0.65
# W60-10:0.8
# W60-11:0.7
# W60-12:0.85
# W60-13:0.55
# W60-14:0.3
# W60-15:0.6
# W60-16:0.25
# W60-17:0.3
# W60-18:0.45
# W60-19:0.35
# W60-20:0.45

# %%
avg_scores_list.std()
# Out:
# np.float64(0.16304360051913847)

# %%
avg_scores_list.mean()
# Out:
# np.float64(0.7171287896885723)

# %%
sns.histplot(avg_scores_list, bins=30, kde=True, stat="density", color="skyblue", alpha=0.6)
plt.show()

# %% [markdown]
# ### <= 0.2 Question analysis

# %%
def low_answer_rate_questions(data, sex, age, low_score_questions_set):

    sample = sample_prep(data, sex, age)
    if sex not in {"M", "W"}:
        raise ValueError("sex not applicable, input one of 'M' or 'W'")
    if age not in {25, 59, 60}:
        raise ValueError("age not applicable, input one of 25, 59, 60")

    col_prefix = f"{sex}{age}-"
    focal_columns = [x for x in sample.columns if x.startswith(col_prefix)]
    
    for col in focal_columns:
        if sample[col].sum() / sample[col].count() <= 0.2:
            low_score_questions_set.add(col)

# %%
low_scoring_questions = set()
for sex in ["M", "W"]:
    for age in [25, 59, 60]:
        sex2 = "Male" if sex == "M" else "Female"
        if age == 25:
            age2 = "18-25"
        elif age == 59:
            age2 = "26-59"
        else:
            age2 = "60+"

        low_answer_rate_questions(data, sex, age, low_scoring_questions)

# %%
low_scoring_questions
# Out:
# {'W59-20'}

# %%
for col in low_scoring_questions:
    print(f"\n{raw_data[col].rename(f'{col}: {scenarios_questions_dict[col]}').value_counts().rename({scenarios_answers_dict[col]: f'Correct: {scenarios_answers_dict[col]}'})}")
# Out:
# W59-20: Rupa, 48, sees her reputation damaged by a colleague’s false rumors at her cooperative society. She feels humiliated but is unsure whether to address it.\r\n\r\nWhat is the best response Rupa should do?
# Privately approach the colleague to clarify concerns and enforce a positive outcome.    18
# Correct: Privately and calmly seek clarification, possibly requesting mediation.         4
# Wait to see if the issue dies down before taking action.                                 1
# Name: count, dtype: int64

# %% [markdown]
# ### >= 0.7 Question analysis

# %%
def high_answer_rate_questions(data, sex, age, high_score_questions_set):

    sample = sample_prep(data, sex, age)
    if sex not in {"M", "W"}:
        raise ValueError("sex not applicable, input one of 'M' or 'W'")
    if age not in {25, 59, 60}:
        raise ValueError("age not applicable, input one of 25, 59, 60")

    col_prefix = f"{sex}{age}-"
    focal_columns = [x for x in sample.columns if x.startswith(col_prefix)]
    
    for col in focal_columns:
        if sample[col].sum() / sample[col].count() >= 0.7:
            high_score_questions_set.add(col)

# %%
high_scoring_questions = set()
for sex in ["M", "W"]:
    for age in [25, 59, 60]:
        sex2 = "Male" if sex == "M" else "Female"
        if age == 25:
            age2 = "18-25"
        elif age == 59:
            age2 = "26-59"
        else:
            age2 = "60+"

        high_answer_rate_questions(data, sex, age, high_scoring_questions)

# %%
len(high_scoring_questions)
# Out:
# 71

# %%
for col in high_scoring_questions:
    print(f"\n{raw_data[col].rename(f'{col}: {scenarios_questions_dict[col]}').value_counts().rename({scenarios_answers_dict[col]: f'Correct: {scenarios_answers_dict[col]}'})}")
# Out:
# M25-5: Sanjay, 19, suddenly feels chest tightness and breathlessness while running a campus marathon. He stops but still can’t catch his breath and feels faint.\r\n\r\nWhat is the best response Sanjay should do?
# Correct: Stop, sit upright, slow his breathing, and ask for help.    20
# Walk around trying to recover on his own.                             3
# Keep jogging, hoping it clears up.                                    2
# Hide symptoms and continue as normal.                                 1
# Name: count, dtype: int64
#
# M60-5: Mr. Menon, 65, feels sudden dizziness and shakiness while walking to the market. He also has excessive sweating and blurry vision. He remembers he did not eat breakfast.\r\n\r\nWhat is the best response Mr. Menon should do?
# Correct: Sit down right away, ask someone nearby if they have anything sweet he can eat, and mention that he’s not feeling well so he can get help if needed.    26
# Name: count, dtype: int64
#
# M60-3: Mr. Naik, 74, feels sudden weakness on one side of his body and has trouble speaking clearly. He struggles to sit up and is alone at home.\r\n\r\nWhat is the best response Mr. Naik should do?
# Correct: Try to call for medical help right away and explain what’s happening as best he can, rather than waiting alone.                   17
# Call a neighbor to come over but downplay how bad the symptoms are, thinking it might not be anything serious.                              4
# Wait until a family member or someone else gets home, planning to tell them about the symptoms so they can help decide what to do next.     1
# Lie down and rest for a while, hoping the weakness and speech trouble will go away if he sleeps it off.                                     1
# Name: count, dtype: int64
#
# M60-8: Mr. Reddy, 70, receives an SMS stating a hefty loan has been approved in his name.\r\n\r\nWhat is the best response Mr. Reddy should do?
# Contact the concerned bank and credit bureau to report the issue.                                          22
# Disregard the message for now, but mentally note to check his credit score later.                           2
# Click the SMS link to check what it is, not planning to give personal information unless it looks real.     1
# Name: count, dtype: int64
#
# M25-14: Sameer, 20, finds his email inbox filled with sign-ups from unknown websites, and warnings of failed payment attempts. He suspects someone has gained access to his email. What is the best response Sameer should do?
# Correct: Change the account password, look through security settings, and enable additional protection like two factor login.    21
# Start by cleaning up the inbox and marking suspicious mails as spam, so the situation feels manageable for now.                   2
# Try to figure things out by asking a tech savvy friend first, and only make changes once he’s sure what’s happening.              2
# Hold off for the moment to see if the unusual messages stop by themselves before taking stronger action.                          1
# Name: count, dtype: int64
#
# W60-7: Meena, 72, receives a call claiming her bank account will be blocked unless she urgently provides her Aadhaar and OTP information.\r\n\r\nWhat is the best response Meena should do?
# Hang up, then call her bank using the number listed on her bank documents.                          16
# Delay action until a family member is available, planning to discuss before making any decision.     8
# Consider giving only part of the information requested to see if the caller seems genuine.           1
# Name: count, dtype: int64
#
# W59-6: Preeti, 38, discovers several large charges made to her credit card that she does not recognize. She hasn’t used her card for any of these purchases. The payment notifications are coming in rapid succession.\r\n\r\nWhat is the best response Preeti should do?
# Correct: Use her bank’s app or call to block the card as soon as possible and tell the bank about the charges.    16
# Wait to go to the bank in person, thinking it’s easier to fix things face-to-face than over the phone or app.      5
# Assume it might just be a bank error and hold off on acting to see if more charges come through.                   2
# Name: count, dtype: int64
#
# M60-1: Mr. Iyer, 72, suddenly experiences severe chest pain and shortness of breath while watching TV alone. He starts sweating and feels dizzy. Fearful, he isn't sure how serious it is.\r\n\r\nWhat is the best response Mr. Iyer should do?
# Correct: Take aspirin and seek help immediately.    22
# Google the symptoms first.                           1
# Call his family but not emergency services.          1
# Name: count, dtype: int64
#
# M59-12: Sanjay, 43, receives alerts about sign-ins from new devices in another city. He fears losing important documents.\r\n\r\nWhat is the best response Sanjay should do?
# Correct: Go into his account settings to change his password, add two-factor authentication, and make sure nobody else can access his email.    26
# Wait and see if he can still log in later, hoping things settle on their own before changing anything important.                                 5
# Share what’s happening with a friend or family member first and discuss what steps might be best before making any changes.                      2
# Log out of his account on as many devices as possible and keep using his current password, thinking that should protect him for now.             1
# Name: count, dtype: int64
#
# M59-6: Rahul, 35, wakes up to see a flood of unfamiliar transactions draining his joint account overnight.\r\n\r\nWhat is the best response Rahul should do?
# Correct: Use his banking app or the helpline to stop further transactions right away and then check what else needs to be reported.    23
# Keep monitoring the account for a day or two, in case the transactions are just temporary holds and disappear on their own.             5
# Contact family members first to see what they suggest before making any changes or reporting anything.                                  2
# Wait to visit a branch in person before doing anything, thinking it’s safer to talk face-to-face so that nothing gets missed.           1
# Name: count, dtype: int64
#
# W25-10: Devika, 25, receives an email with a PDF “invoice” attachment and a message stating an urgent charge for an unknown purchase.\r\n\r\nWhat is the best response Devika should do?
# Do not open the PDF; verify independently using her bank app or statement.                                      22
# Open the PDF and quickly review the “invoice” for more details, planning to close it if it looks suspicious.     3
# Choose not to act for now, hoping there’s no follow-up.                                                          1
# Respond to the email with questions about the transaction before checking with her bank.                         1
# Name: count, dtype: int64
#
# W25-18: Diya, 18, is pressured by her peers to drink alcohol at a college fest, despite her strong reservations. She feels anxious and cornered.\r\n\r\nWhat is the best response Diya should do?
# Correct: Say clearly that she doesn’t want to drink and, if things feel too uncomfortable, move away from the group for a bit.    19
# Stay close to the group but quietly avoid the alcohol, hoping the others stop bringing it up.                                      2
# Politely say no to the drink but stick around with her friends as long as she feels okay.                                          2
# Change the topic or suggest another activity so the group focuses on something else instead of her decision.                       1
# Name: count, dtype: int64
#
# W59-3: Manisha, 42, wakes up with a sudden, partial loss of vision and numbness on one side of her body. She struggles to move and can barely speak clearly. She is alone at home.\r\n\r\nWhat is the best response Manisha should do?
# Correct: Call emergency medical services at once.    20
# Wait for family to return home.                       3
# Lie down and try to rest.                             1
# Name: count, dtype: int64
#
# W60-1: Asha, 68, suddenly feels tightness in her chest and shortness of breath at home.\r\n\r\nWhat is the best response Asha should do?
# Correct: Take an aspirin if she has one, call for help straight away, and let someone know what she’s feeling.    17
# Look up possible remedies online and try some suggestions at home to see if they help.                             6
# Lie down quietly and wait for a while to see if her symptoms get better on their own.                              1
# Wait until a family member arrives before deciding whether to act.                                                 1
# Name: count, dtype: int64
#
# W59-15: Chhavi, 32, finds her private documents uploaded online without her consent after her shared drive was hacked. She is outraged and humiliated but unsure how to respond. What is the best response Chhavi should do?
# Save evidence, secure accounts, and reach out for support while reporting.     18
# Avoid logging in to her accounts until she feels calmer.                        2
# Remove remaining files from the shared drive to prevent more leaks.             2
# Talk to friends for advice on next steps before taking action.                  1
# Name: count, dtype: int64
#
# W25-11: Priyanka, 20, receives a message that her Instagram account will be terminated unless she clicks a given link and verifies her identity within the hour. The message looks official and contains a logo. She is worried about losing her followers.\r\n\r\nWhat is the best response Priyanka should do?
# Correct: Skip clicking the link, open her Instagram app directly to check for any issues, and consider updating her account’s security settings.    18
# Share the message with a friend who knows about technology and see what they think before acting.                                                    8
# Forward the message to several friends to find out if anyone else received something similar, hoping that helps her decide.                          1
# Name: count, dtype: int64
#
# W59-18: Leena, 52, begins to notice that friends exclude her from important gatherings and conversations. She feels growing loneliness at home but hides it. She worries it is her fault.\r\n\r\nWhat is the best response Leena should do?
# Reach out to a trusted friend or counselor and share her feelings honestly.     15
# Continue reaching out to friends even if they sometimes don’t respond.           3
# Join in group chats more actively, hoping inclusion improves.                    3
# Mention to a close friend that she’s feeling a bit left out.                     2
# Name: count, dtype: int64
#
# M60-11: Mr. Deshmukh, 70, gets a message that his pension account will be blocked unless he clicks a link to “re-verify” immediately. The message is urgent and appears official.\r\n\r\nWhat is the best response Mr. Deshmukh should do?
# Correct: Log in using the bank’s app he usually uses, or wait to ask someone at his branch about the alert.         17
# Save the message and dial the phone number provided just in case it’s real, hoping that’ll clear up any concern.     4
# Ask a family member for help with the message first before deciding what to do about his account.                    2
# Click the link out of caution, reasoning he can always check with the bank afterwards if something seems wrong.      1
# Name: count, dtype: int64
#
# M25-16: Nikhil, 20, faces cyberbullying in a college social group where rumors and jokes about him are being spread. He feels targeted and isolated.\r\n\r\nWhat is the best response Nikhil should do?
# Correct: Take screenshots of the posts and messages, and then reach out to a trusted authority figure or counsellor who can step in to support him.    19
# Privately message one of those making fun of him to ask why they are targeting him, hoping to resolve it one on one.                                    6
# Decide not to say anything for now, leave notifications on, and just avoid replying to the group until things calm down.                                1
# Quietly mention what’s going on to a close friend and ask for their thoughts before doing anything official.                                            1
# Name: count, dtype: int64
#
# W59-14: Sunita, 50, finds her Facebook account posting strange ads and messages without her knowledge. Friends alert her to spam coming from her profile. She’s confused how it happened.\r\n\r\nWhat is the best response Sunita should do?
# Correct: Change her password and secure her account.           18
# Think about deleting her account if the problem continues.      4
# Ask a tech-savvy friend for ideas before changing anything.     2
# Apologize to friends and wait for the issue to settle.          1
# Name: count, dtype: int64
#
# W25-16: Ananya, 21, is the target of cyberbullying in a college WhatsApp group where personal details and insults are being spread rapidly. She feels isolated and embarrassed.\r\n\r\nWhat is the best response Ananya should do?
# Save screenshots as evidence and approach a counselor or a trusted adult for help.     23
# Block or mute key people in the group to create space.                                  3
# Stay in the group but minimize social media use for a short period.                     1
# Name: count, dtype: int64
#
# M60-9: Mr. Patel, 73, is encouraged by a distant relative to invest his retirement savings in an “exclusive gold scheme.” What is the best response Mr. Patel should do?
# Decline and independently research the investment scheme.                                                                               18
# Bring up the scheme in casual conversations with his friends to hear their opinions, thinking their advice will inform his decision.     3
# Test the scheme with a small stake, rationalizing that even minor gains will show if it is safe.                                         3
# Name: count, dtype: int64
#
# W59-1: Anjali, 34, develops sudden chest pain and shortness of breath while working from home. She is alone and begins to sweat profusely. She’s unsure if it’s serious.\r\n\r\nWhat is the best response Anjali should do?
# Correct: Take an aspirin if it’s available, call for help, and let someone know about her symptoms.               17
# Look up remedies online and try out suggestions she finds at home, hoping the pain and breathing will improve.     4
# Call her spouse and wait for them to come home without taking any further steps right away.                        2
# Stay put and see if her chest pain and breathlessness improve on their own while she tries to relax.               1
# Name: count, dtype: int64
#
# M25-7: Rohan, 22, receives a call from someone claiming to be a police officer, demanding payment.\r\n\r\nWhat is the best response Rohan should do?
# Correct: Hang up the call without giving any information, then look up and contact the official police station independently to check if the demand was real.    22
# Transfer a small part of the requested payment electronically to see what happens next, thinking he might buy time and spot whether it’s genuine or not.          4
# Call back the phone number that contacted him to ask for more details about the demand, believing he can spot a scam if they sound suspicious.                    3
# Name: count, dtype: int64
#
# W25-13: Kavya, 21, receives a call from someone pretending to be a “digital wallet helpline” asking for her OTP to resolve an issue. She feels pressured as the caller is persistent.\r\n\r\nWhat is the best response Kavya should do?
# Correct: Say no to sharing her OTP, end the call, and check with the actual wallet app’s helpline to see if there really is a problem.    24
# Tell the caller she’ll get back to them after she has time to think, and wait before making any decisions.                                 1
# Name: count, dtype: int64
#
# M59-15: Anil, 27, finds his personal financial documents circulating online after his cloud account was accessed without permission. He feels shocked and exposed.\r\n\r\nWhat is the best response Anil should do?
# Correct: Save any evidence of what happened, review and tighten the security on his accounts, and look for help reporting the breach.    23
# Stay quiet about it for now and avoid posting anything online, deciding to wait and see if anyone contacts him or if it blows over.       4
# Reach out to someone he trusts for advice on how to handle the situation and whether he should take any action right away.                4
# Start deleting as much of his online content as possible before checking his security settings, hoping this limits further damage.        2
# Name: count, dtype: int64
#
# M60-6: Mr. Sharma, 68, finds multiple unauthorized transactions rapidly draining his pension account.\r\n\r\nWhat is the best response Mr. Sharma should do?
# Correct: Call his bank’s helpline right away to talk about what’s happening and find out how to stop further transactions.    24
# Get in touch with his son and see what advice he has before deciding what to do next.                                          1
# Name: count, dtype: int64
#
# W25-8: Nidhi, 21, receives a notification that her loan approval is complete for a loan she never applied for, and her credit report shows a large debt. What is the best response Nidhi should do?
# Correct: Contact her bank and the credit bureau as soon as possible to report the problem and ask what steps she should take.    24
# Do nothing for now, figuring it’s probably just spam and will go away by itself.                                                  2
# Call the number from the message and try to judge if it’s legitimate based on how they respond.                                   1
# Name: count, dtype: int64
#
# W60-3: Parvati, 70, suddenly loses vision in one eye while reading.\r\n\r\nWhat is the best response Parvati should do?
# Correct: Stop reading, call for help, and get to the hospital.    19
# Sprinkle eyes with water hoping it will clear the vision.          5
# Continue her activities, ignoring the issue.                       1
# Name: count, dtype: int64
#
# W60-11: Rekha, aged 68, receives a message that her “WhatsApp account will be deleted in 24 hours” unless she clicks a link. \r\n\r\nWhat is the best response Rekha should do?
# Correct: Verify with someone she trusts and ignore the suspicious message.    16
# Pause, double-check with a trusted family member before clicking the link.     7
# Ignore the message and stop using WhatsApp, uncertain what to do.              1
# Click the link to avoid losing her WhatsApp and see if it helps.               1
# Name: count, dtype: int64
#
# W25-7: Mehak, 24, receives a call from someone claiming to be from a government office, threatening legal action unless she immediately pays a "pending fine" online.\r\n\r\nWhat is the best response Mehak should do?
# Hang up, then verify the demand with official government contacts.                            21
# Pause and wait until she can talk to family, feeling too anxious to decide alone.              2
# Make a small payment now just in case, afraid she’ll get into trouble if she waits.            1
# Try bargaining on the call, reasoning that an official would allow her to settle for less.     1
# Name: count, dtype: int64
#
# M25-6: Aman, 20, wakes up to SMS alerts showing multiple unfamiliar transactions draining his account overnight.\r\n\r\nWhat is the best response Aman should do?
# Correct: Try calling or messaging the bank’s helpline right away to report the situation and at the same time use the app to freeze or block his card if possible.    21
# Try not to panic, but plan to visit the closest bank branch in person as soon as it opens to sort out what happened face-to-face.                                      5
# Wait to see if the bank automatically fixes things by lunchtime, thinking it could be an error that corrects itself, before reaching out.                              2
# Name: count, dtype: int64
#
# W25-9: Ankita, 23, is tempted by a popular influencer’s “limited time crypto investment scheme”.\r\n\r\nWhat is the best response Ankita should do?
# Correct: Look up details about the scheme using official sites or check what financial regulators say before deciding what to do next.    19
# Ask around in her social circles to get opinions and advice before making any decisions.                                                   4
# Invest a small amount first, thinking that it’s a safe way to test how genuine the opportunity is.                                         2
# Trust her flatmates and the influencer’s recommendations and go ahead with the investment.                                                 1
# Name: count, dtype: int64
#
# M60-7: Mr. Banerjee, 74, receives a phone call from someone claiming to be from the Income Tax Department, threatening arrest unless a “fee” is paid instantly. \r\n\r\nWhat is the best response Mr. Banerjee should do?
# Correct: Hang up and call the Income Tax Department on the number he normally uses, just to make sure the request from the caller is actually genuine.    18
# Try calling the same number back to see if the caller can prove they’re from the government office, hoping to catch a scam if it’s fake.                   6
# Transfer a small part of the requested fee right away to avoid trouble, planning to check with someone later if the payment was really needed.             1
# Name: count, dtype: int64
#
# M60-14: Mr. Prasad, 66, receives messages from friends about suspicious posts appearing from his social media profile. He also gets locked out after failed login attempts.\r\n\r\nWhat is the best response Mr. Prasad should do?
# Correct: Try to recover his account using the recovery process, and let his contacts know so they’re aware something unusual is happening.    20
# Send a message to the group apologizing for the posts and asking if anyone knows what could be done in this situation.                         4
# Wait a bit and ask friends if the suspicious posts keep appearing before trying anything himself.                                              1
# Name: count, dtype: int64
#
# M60-2: Mr. Gupta, 67, eats sweets at a family event and his lips, face, and throat begin swelling rapidly. He finds it hard to breathe and his voice is muffled.\r\n\r\nWhat is the best response Mr. Gupta should do?
# Correct: Take his allergy medicine if he has it, and ask someone nearby to get urgent medical help instead of waiting to see if it improves.    22
# Drink some water slowly and hope it helps ease the swelling, planning to wait a bit before doing anything more.                                  3
# Name: count, dtype: int64
#
# W59-2: Shruti, 49, eats a snack at a wedding and within minutes feels her lips and throat swelling. She starts experiencing difficulty breathing. She remembers a doctor once mentioned a potential food allergy.\r\n\r\nWhat is the best response Shruti should do?
# Correct: Take her allergy medicine if she has it, and get someone to call for medical help right away.    17
# Call a family member to ask what she should do, before deciding on next steps.                             4
# Drink some water and wait to see if the swelling and breathing trouble settle on their own.                2
# Name: count, dtype: int64
#
# W60-5: Shobha, 77, discovers that her medication pills look different than usual after a recent refill.What would be a sensible step for Shobha to take after noticing this change?
# Correct: Pause before taking the pills, call the pharmacy to explain what she’s noticed, and ask if there’s been any change to her prescription.    18
# Go ahead and take the medication, thinking that changes in appearance sometimes happen.                                                              3
# Check with her friends or a chat group to see if anyone else has experienced something similar, and ask what they did.                               2
# Decide not to worry about the packaging or pill color and keep using the medication as directed.                                                     2
# Name: count, dtype: int64
#
# M60-10: Mr. Singh, 66, receives an email alert asking him to urgently update his KYC details via a provided link.\r\n\r\nWhat is the best response Mr. Singh should do?
# Correct: Get in touch with his bank using the official website or stop by in person to ask if the alert is genuine before taking any action.    20
# Ignore the message for now and wait to see if the bank reaches out again with more information or reminders.                                     4
# Forward the email to family members first and ask what they think he should do about it.                                                         1
# Name: count, dtype: int64
#
# W59-10: Neha, 47, receives an email supposedly from her bank asking her to update KYC details by clicking a link or risk account suspension. \r\n\r\nWhat is the best response Neha should do?
# Correct: Use her bank’s app or visit the branch to see if her KYC is actually pending before responding to the email.    17
# Share the email with family to get their advice on what to do next.                                                       4
# Ignore the email for now, feeling unsure but hoping it’s not a real issue.                                                2
# Click the link to see what’s being asked, deciding she’ll leave if anything seems off.                                    1
# Name: count, dtype: int64
#
# M25-20: Tushar, 21, feels crushing loneliness after being left out of a close friend group’s trip. He starts skipping classes and social activities.\r\n\r\nWhat is the best response Tushar should do?
# Talk honestly about his feelings with a supportive friend, mentor, or counselor.     15
# Bring up his feelings in a group chat if the chance comes up.                         5
# Try new activities solo to see if that helps improve his mood.                        4
# Confide in a classmate about feeling left out, hoping for advice.                     2
# Name: count, dtype: int64
#
# M25-11: Aditya, 24, gets a WhatsApp message claiming his account will be permanently deleted unless he clicks a link for verification. The message looks official and he’s worried about losing his chats. What is the best response Aditya should do?
# Ignore the link, verify status in-app, and enable security features.     18
# Ask a friend first if they’ve seen these kinds of messages.               5
# Avoid using WhatsApp until deciding what’s safe.                          3
# Click the link just to see if it’s actually a threat.                     1
# Name: count, dtype: int64
#
# M59-5: Suresh, 48, starts sweating, shaking, and feels faint while commuting in the metro. He realizes he skipped both breakfast and lunch and is now feeling extremely weak.\r\n\r\nWhat is the best response Suresh should do?
# Correct: Sit down if possible, mention to someone nearby that he’s feeling unwell, and ask for anything sweet or sugary he can have while he waits for help.    26
# Remain standing even as he feels shaky and light-headed, telling himself he needs to push through until he reaches his destination.                              5
# Avoid making a scene, ignore his discomfort as best as he can, and wait until he gets home before taking care of his symptoms.                                   2
# Stay seated and quietly hope the weakness passes on its own, planning to grab food once he arrives at his stop.                                                  2
# Name: count, dtype: int64
#
# W25-6: Riya, 22, wakes up to several unexplained debit messages from her bank account, totaling most of her semester’s tuition savings.\r\n\r\nWhat is the best response Riya should do?
# Correct: Use her banking app or call the helpline right away to block her card and inform the bank about what’s happened.    18
# Plan to visit her bank once it opens, thinking an in-person visit is the only proper way to deal with it.                     7
# Message her friends to ask for advice first, since she isn’t sure what steps to take in this situation.                       1
# Name: count, dtype: int64
#
# M60-13: Mr. Joshi, 74, receives a call purportedly from “technical support,” asking him to install a remote access app to resolve a banking problem. The caller is persuasive and uses technical language.\r\n\r\nWhat is the best response Mr. Joshi should do?
# Refuse, disconnect, and verify with his bank directly.                          18
# Tell the caller he'll need to speak to his bank first before doing anything.     4
# Install the remote access app since the caller seems knowledgeable.              2
# Name: count, dtype: int64
#
# W25-19: Aarti, 24, receives inappropriate messages from a teaching assistant but is worried about complaining due to academic repercussions. She feels helpless but wants the behavior to stop.\r\n\r\nWhat is the best response Aarti should do?
# Correct: Keep the messages as evidence and reach out to the student support office or someone at the university who can help.    24
# Reply directly to the teaching assistant and ask them to stop sending such messages, hoping that will resolve it.                 3
# Try to avoid further conversations with the teaching assistant, hoping the situation will improve if she keeps her distance.      1
# Name: count, dtype: int64
#
# W60-2: Lakshmi, 75, slips in the bathroom and cannot get up due to severe hip pain.\r\n\r\nWhat is the best response Lakshmi should do?
# Correct: Stay still and shout for assistance.    16
# Try to stand up by herself.                       5
# Wait to see if pain lessens on its own.           3
# Try to reach out for pain medication.             1
# Name: count, dtype: int64
#
# W25-15: Ruchika, 25, finds her private photographs have been leaked online and shared without her consent. She feels violated and anxious.\r\n\r\nWhat is the best response Ruchika should do?
# Save evidence and alert someone she trusts while preparing to report.                   22
# Ask trusted friends what steps she could take first.                                     2
# Try to block or report the account spreading photos but not contact anyone else yet.     1
# Consider deactivating her accounts temporarily while she figures out what to do.         1
# Name: count, dtype: int64
#
# W60-12: Malati, 70, is logged out of her email and the recovery instructions are in English, which she finds hard to understand.\r\n\r\nWhat is the best response Malati should do?
# Ask a trusted family member or neighbor for help reading the instructions.     18
# Try leaving the account unused for a while and manage without email.            4
# Call a number that appeared in a pop-up window to ask for help.                 3
# Name: count, dtype: int64
#
# W25-4: Sneha, 20, accidentally injures her hand on a rusty nail during a college event, and it starts bleeding profusely. She is unsure about her last tetanus shot.\r\n\r\nWhat is the best response Sneha should do?
# Correct: Clean the wound, press to stop the bleeding, and get someone to take her to a clinic.      19
# Use some antiseptic cream on the wound and wait to see if it gets better without going anywhere.     5
# Stay where she is and wait for someone nearby to help, hoping they’ll know what to do.               2
# Name: count, dtype: int64
#
# W25-14: Isha, 22, notices her email has been used to sign up for several services she doesn’t know. She receives spam and warnings about failed payments.\r\n\r\nWhat is the best response Isha should do?
# Correct: Go into her email account, update her password and add some extra security options.                                18
# Mark the unfamiliar emails as spam and delete them, figuring that will cut down on further messages and sort things out.     4
# Wait to see if the subscriptions and warnings stop on their own after some time, hoping it’s just a temporary issue.         2
# Ask a classmate if they’ve dealt with something similar and see what steps they recommend before making changes.             1
# Name: count, dtype: int64
#
# W59-19: Jyoti, 33, is pressured by in-laws to assume full caregiving for an ill relative despite her work commitments. She feels overwhelmed but fears saying no will cause family friction.\r\n\r\nWhat is the best response Jyoti should do?
# Correct: Talk honestly and respectfully with her in-laws about boundaries and shared responsibilities.    16
# Suggest small changes to distribute tasks more evenly within the family.                                   3
# Discuss her concerns with a close family member soon.                                                      3
# Quietly take on the role but seek help from her partner if it becomes too much.                            1
# Name: count, dtype: int64
#
# M59-8: Sunil, 46, receives a text that a hefty loan has been sanctioned in his name.\r\nWhat is the best response Sunil should do?
# Check his credit report with an official bureau and contact the bank.                                   22
# Click the cancellation link to see what happens, intending not to give details unless it seems okay.     6
# Delete the SMS and delay doing anything, figuring it’ll work out.                                        5
# Forward the SMS to a family member and ask them what they think he should do.                            1
# Name: count, dtype: int64
#
# M59-1: Mukesh, 39, experiences a sudden, crushing chest pain and sweats profusely while at home alone. He feels short of breath and dizzy. Unsure if it’s gas or a heart attack, he delays.\r\n\r\nWhat is the best response Mukesh should do?
# Correct: Take an aspirin to reduce the risk of heart trouble, then call emergency services.                                     21
# Search online about chest pain symptoms to compare what he’s feeling and decide if it might really be a heart attack or not.     4
# Sit down quietly and wait for a while, hoping the pain is just indigestion or gas and might ease on its own.                     4
# Try calling his wife first to tell her what’s happening and wait to hear what she suggests before doing anything else.           4
# Name: count, dtype: int64
#
# W25-12: Aishwarya, 23, notices unauthorized UPI transactions on her phone after connecting to café Wi-Fi. Several payments have already gone through.\r\n\r\nWhat is the best response Aishwarya should do?
# Correct: Use her banking app to block UPI transactions right away and let her bank know what’s happened.               23
# Keep checking her bank app for more details and wait to see if any new alerts pop up before deciding on next steps.     2
# Decide to wait and call her bank later, thinking they’ll be able to sort things out when she has more time.             1
# Ask the friends she’s with what they think she should do about the unexpected payments before acting.                   1
# Name: count, dtype: int64
#
# W60-10: Anita, 70, is notified that her fixed deposit is due for renewal and receives a suspicious email link to “renew now.”\r\n\r\nWhat is the best response Anita should do?
# Correct: Check her fixed deposit status by logging into her usual banking app or visiting her bank.              16
# Use the helpline number included in the email to ask about the renewal, thinking it might be more convenient.     5
# Hold off on responding to the email, deciding to deal with the renewal at a later time.                           2
# Click the link and look over what’s being asked, planning to stop if it seems strange.                            2
# Name: count, dtype: int64
#
# M25-2: Vikram, 21, eats a dessert at a party and suddenly has swelling of his lips and tongue, struggling to breathe. People around are not sure what’s happening. He recalls having a food allergy as a child.\r\n\r\nWhat is the best response Vikram should do?
# Correct: Use allergy medication if available and call for emergency help.    23
# Drink water and wait a while.                                                 2
# Call a friend for advice first.                                               1
# Hope the swelling goes down on its own.                                       1
# Name: count, dtype: int64
#
# W25-5: Simran, 25, finds herself suddenly struggling to breathe and wheezing during an early-morning run. She has a history of mild asthma but is alone and has no inhaler on hand. What is the best response Simran should do?
# Correct: Sit down and focus on slowing her breathing, then look for a way to get help, rather than continuing her run.    21
# Stay in place and do nothing for now, thinking the wheezing might go away if she just waits awhile.                        4
# Slow down to a walk and wait for a bit to see if her symptoms improve before making any decisions.                         1
# Push through the discomfort and keep running, hoping her breathing settles if she doesn’t stop.                            1
# Name: count, dtype: int64
#
# M60-19: Mr. Mishra, 70, is unexpectedly asked to care for his grandchildren for a week while his children travel, but feels physically and emotionally overwhelmed by the responsibility. What is the best response Mr. Mishra should do?
# Tell his family honestly that he needs help and identify specific support he’d appreciate.     19
# Ask a trusted neighbor for temporary assistance when needed.                                    2
# Agree but check in with his children if the responsibility becomes too much.                    1
# Find time for himself only when the kids are busy.                                              1
# Name: count, dtype: int64
#
# M60-12: Mr. Rao, 68, gets email alert that show sign-ins from unknown locations. He is worried about losing contact with his friends and getting scammed.\r\n\r\nWhat is the best response Mr. Rao should do?
# Change his password and set up two-factor authentication.                       20
# Wait a few hours to see if the problem resolves itself.                          2
# Ask a family member to help check what’s happening before changing anything.     1
# Name: count, dtype: int64
#
# M59-11: Deepak, 34, gets an SMS warning that his bank account will be blocked unless he “verifies” it through a suspicious link. The message appears urgent and bears his bank’s logo.\r\n\r\nWhat is the best response Deepak should do?
# Correct: Open his bank’s app or log in through his usual method to see if there are any actual alerts about his account, rather than using the link in the message.    25
# Call the phone number listed in the SMS and ask for more information, deciding how to respond based on what they say.                                                   4
# Forward the SMS to someone he trusts and see what advice or opinions they have before taking any action.                                                                4
# Name: count, dtype: int64
#
# M59-16: Tejas, 37, is repeatedly excluded from team meetings and after-work events at his office. His projects are reassigned without explanation, leaving him isolated and anxious.\r\n\r\nWhat is the best response Tejas should do?
# Correct: Arrange to talk privately with his supervisor or someone in HR, and respectfully ask about the changes and exclusions to understand what’s behind them.    23
# Bring up the issue in a casual conversation with a colleague to get their honest take before deciding how to handle things.                                          5
# Make an effort to be less involved or visible at work for a while, thinking it might avoid drawing attention to the problem.                                         3
# Share his concerns informally in a group chat to see if anyone else has experienced similar treatment or noticed what’s happening.                                   1
# Name: count, dtype: int64
#
# M59-2: Praveen, 56, eats at a wedding and soon his face and tongue start swelling and he finds it hard to breathe. He knows he’s allergic to certain nuts but doesn’t recall if he had them.\r\n\r\nWhat is the best response Praveen should do?
# Correct: Use the allergy medicine he carries with him—like an antihistamine—and at the same time ask someone nearby to get emergency help.    24
# Step outside for some air and rest quietly, hoping the symptoms will start to settle down on their own.                                        4
# Quickly pull aside a close relative or friend to explain what’s happening and get their advice before acting.                                  3
# Take a few sips of water to see if the swelling eases and wait a little before deciding what else to do.                                       2
# Name: count, dtype: int64
#
# W60-4: Vimala, 63, experiences sudden confusion and inability to recognize common objects in her kitchen.\r\n\r\nWhat is the best response Vimala should do?
# Correct: Move to a safe spot, let a nearby neighbor know she’s confused, and ask for help getting checked by a doctor.    17
# Wait a while and hope her memory becomes clearer before taking any action.                                                 4
# Ignore the confusion for now and keep doing her usual tasks to see if it passes.                                           3
# Try to finish what she was doing and then take a break to rest and see if the confusion goes away.                         1
# Name: count, dtype: int64
#
# M59-3: Aditya, 42, wakes up with blurred vision and can’t move his right hand. He tries to speak, but the words come out slurred. There’s no one else at home.\r\n\r\nWhat is the best response Aditya should do?
# Correct: Grab his phone and dial emergency services straight away, telling them what’s happening even if his words come out unclear, and stay put until help arrives.    25
# Lie back down on the bed and rest for a while, thinking the weakness and speech problem might fade once he’s had more sleep.                                              4
# Wait until a family member gets home, planning to explain the situation then and decide together what should be done.                                                     3
# Try getting the attention of a nearby neighbor for help, and hesitate to fully describe the seriousness of the symptoms out of worry that he might be overreacting.       1
# Name: count, dtype: int64
#
# M60-4: Mr. Basu, 71, cuts his hand deeply while gardening, and the bleeding is heavy. He panics, unsure what to do before seeking help.\r\n\r\nWhat is the best response Mr. Basu should do?
# Correct: Apply pressure and elevate the hand, then get help.    18
# Cover wound and sit quietly.                                     3
# Run water over the wound continuously.                           3
# Name: count, dtype: int64
#
# W60-6: Sushma, a 67-year-old widow, discovers that her entire pension payout for the month has suddenly disappeared from her bank account without her knowledge.\r\n\r\nWhat is the best response Sushma should do?
# Correct: Call the bank’s customer service line right away to report the missing money and freeze her account.                      19
# Wait until the next day to visit the bank in person, hoping talking face-to-face with the branch manager will help sort it out.     3
# Ask a neighbor if they’ve ever faced something similar and get their thoughts before deciding what to do.                           3
# Name: count, dtype: int64
#
# M25-4: Prateek, 22, suddenly feels intense pain and swelling after stepping on a rusty nail during a cricket game. The wound is deep and bleeding. He is worried about infection but unsure what to do.\r\nWhat is the best response Prateek should do?
# Correct: Clean the wound carefully, press to control the bleeding, cover it, and arrange to see a doctor right away.    18
# Try to wipe the wound with a cloth and keep playing, planning to properly clean and treat it after the game.             4
# Rinse the wound quickly with available water, cover it for now, and then check later if it still seems serious.          3
# Call a teammate over for their advice first and decide based on what they suggest.                                       2
# Name: count, dtype: int64
#
# M59-10: Irfan, 29, receives what looks like an official bank email urging him to click a link and update his KYC.\r\nWhat is the best response Irfan should do?
# Correct: Check his KYC status using the bank’s app or by logging in the usual way, without using the link in the email.    22
# Click the link and enter just the basics to see if it goes anywhere, then decide what to do next.                           3
# Decide to ignore the email for now and just wait to see if any further reminders come.                                      3
# Forward the message to someone in his family and ask if they’ve received anything similar before deciding.                  2
# Name: count, dtype: int64
#
# W60-8: Rani, aged 65, notices a loan has appeared on her credit report which she never took.\r\n\r\nWhat is the best response Rani should do?
# Correct: Contact her bank or credit service to ask about placing a fraud alert on her credit profile.             19
# Hold off on taking any steps until she can talk with a friend who may have handled something like this before.     3
# Assume it’s just a simple error that should get fixed automatically, so check her report again after a week.       2
# Drop by her local police station to discuss the situation and get their input before deciding what to do.          1
# Name: count, dtype: int64
#
# W25-17: Shreya, 25, discovers her roommate is spreading rumors about her in their PG hostel, leading to social exclusion. She becomes withdrawn and anxious in the common areas.\r\n\r\nWhat is the best response Shreya should do?
# Have a calm one-on-one conversation with her roommate or talk to the hostel warden.     22
# Talk through the issue first with a mutual friend, seeking suggestions.                  2
# Write a short message to her roommate expressing discomfort with the situation.          2
# Name: count, dtype: int64

# %% [markdown]
# ### >= 0.8 Question analysis

# %%
def high_answer_rate_questions(data, sex, age, high_score_questions_set):

    sample = sample_prep(data, sex, age)
    if sex not in {"M", "W"}:
        raise ValueError("sex not applicable, input one of 'M' or 'W'")
    if age not in {25, 59, 60}:
        raise ValueError("age not applicable, input one of 25, 59, 60")

    col_prefix = f"{sex}{age}-"
    focal_columns = [x for x in sample.columns if x.startswith(col_prefix)]
    
    for col in focal_columns:
        if sample[col].sum() / sample[col].count() >= 0.8:
            high_score_questions_set.add(col)

# %%
high_scoring_questions = set()
for sex in ["M", "W"]:
    for age in [25, 59, 60]:
        sex2 = "Male" if sex == "M" else "Female"
        if age == 25:
            age2 = "18-25"
        elif age == 59:
            age2 = "26-59"
        else:
            age2 = "60+"

        high_answer_rate_questions(data, sex, age, high_scoring_questions)

# %%
len(high_scoring_questions)
# Out:
# 40

# %%
for col in high_scoring_questions:
    print(f"\n{raw_data[col].rename(f'{col}: {scenarios_questions_dict[col]}').value_counts().rename({scenarios_answers_dict[col]: f'Correct: {scenarios_answers_dict[col]}'})}")
# Out:
# M25-5: Sanjay, 19, suddenly feels chest tightness and breathlessness while running a campus marathon. He stops but still can’t catch his breath and feels faint.\r\n\r\nWhat is the best response Sanjay should do?
# Correct: Stop, sit upright, slow his breathing, and ask for help.    20
# Walk around trying to recover on his own.                             3
# Keep jogging, hoping it clears up.                                    2
# Hide symptoms and continue as normal.                                 1
# Name: count, dtype: int64
#
# M60-5: Mr. Menon, 65, feels sudden dizziness and shakiness while walking to the market. He also has excessive sweating and blurry vision. He remembers he did not eat breakfast.\r\n\r\nWhat is the best response Mr. Menon should do?
# Correct: Sit down right away, ask someone nearby if they have anything sweet he can eat, and mention that he’s not feeling well so he can get help if needed.    26
# Name: count, dtype: int64
#
# M60-8: Mr. Reddy, 70, receives an SMS stating a hefty loan has been approved in his name.\r\n\r\nWhat is the best response Mr. Reddy should do?
# Contact the concerned bank and credit bureau to report the issue.                                          22
# Disregard the message for now, but mentally note to check his credit score later.                           2
# Click the SMS link to check what it is, not planning to give personal information unless it looks real.     1
# Name: count, dtype: int64
#
# M25-14: Sameer, 20, finds his email inbox filled with sign-ups from unknown websites, and warnings of failed payment attempts. He suspects someone has gained access to his email. What is the best response Sameer should do?
# Correct: Change the account password, look through security settings, and enable additional protection like two factor login.    21
# Start by cleaning up the inbox and marking suspicious mails as spam, so the situation feels manageable for now.                   2
# Try to figure things out by asking a tech savvy friend first, and only make changes once he’s sure what’s happening.              2
# Hold off for the moment to see if the unusual messages stop by themselves before taking stronger action.                          1
# Name: count, dtype: int64
#
# M60-1: Mr. Iyer, 72, suddenly experiences severe chest pain and shortness of breath while watching TV alone. He starts sweating and feels dizzy. Fearful, he isn't sure how serious it is.\r\n\r\nWhat is the best response Mr. Iyer should do?
# Correct: Take aspirin and seek help immediately.    22
# Google the symptoms first.                           1
# Call his family but not emergency services.          1
# Name: count, dtype: int64
#
# M59-12: Sanjay, 43, receives alerts about sign-ins from new devices in another city. He fears losing important documents.\r\n\r\nWhat is the best response Sanjay should do?
# Correct: Go into his account settings to change his password, add two-factor authentication, and make sure nobody else can access his email.    26
# Wait and see if he can still log in later, hoping things settle on their own before changing anything important.                                 5
# Share what’s happening with a friend or family member first and discuss what steps might be best before making any changes.                      2
# Log out of his account on as many devices as possible and keep using his current password, thinking that should protect him for now.             1
# Name: count, dtype: int64
#
# M59-6: Rahul, 35, wakes up to see a flood of unfamiliar transactions draining his joint account overnight.\r\n\r\nWhat is the best response Rahul should do?
# Correct: Use his banking app or the helpline to stop further transactions right away and then check what else needs to be reported.    23
# Keep monitoring the account for a day or two, in case the transactions are just temporary holds and disappear on their own.             5
# Contact family members first to see what they suggest before making any changes or reporting anything.                                  2
# Wait to visit a branch in person before doing anything, thinking it’s safer to talk face-to-face so that nothing gets missed.           1
# Name: count, dtype: int64
#
# W25-10: Devika, 25, receives an email with a PDF “invoice” attachment and a message stating an urgent charge for an unknown purchase.\r\n\r\nWhat is the best response Devika should do?
# Do not open the PDF; verify independently using her bank app or statement.                                      22
# Open the PDF and quickly review the “invoice” for more details, planning to close it if it looks suspicious.     3
# Choose not to act for now, hoping there’s no follow-up.                                                          1
# Respond to the email with questions about the transaction before checking with her bank.                         1
# Name: count, dtype: int64
#
# W25-18: Diya, 18, is pressured by her peers to drink alcohol at a college fest, despite her strong reservations. She feels anxious and cornered.\r\n\r\nWhat is the best response Diya should do?
# Correct: Say clearly that she doesn’t want to drink and, if things feel too uncomfortable, move away from the group for a bit.    19
# Stay close to the group but quietly avoid the alcohol, hoping the others stop bringing it up.                                      2
# Politely say no to the drink but stick around with her friends as long as she feels okay.                                          2
# Change the topic or suggest another activity so the group focuses on something else instead of her decision.                       1
# Name: count, dtype: int64
#
# W59-3: Manisha, 42, wakes up with a sudden, partial loss of vision and numbness on one side of her body. She struggles to move and can barely speak clearly. She is alone at home.\r\n\r\nWhat is the best response Manisha should do?
# Correct: Call emergency medical services at once.    20
# Wait for family to return home.                       3
# Lie down and try to rest.                             1
# Name: count, dtype: int64
#
# W60-1: Asha, 68, suddenly feels tightness in her chest and shortness of breath at home.\r\n\r\nWhat is the best response Asha should do?
# Correct: Take an aspirin if she has one, call for help straight away, and let someone know what she’s feeling.    17
# Look up possible remedies online and try some suggestions at home to see if they help.                             6
# Lie down quietly and wait for a while to see if her symptoms get better on their own.                              1
# Wait until a family member arrives before deciding whether to act.                                                 1
# Name: count, dtype: int64
#
# W59-15: Chhavi, 32, finds her private documents uploaded online without her consent after her shared drive was hacked. She is outraged and humiliated but unsure how to respond. What is the best response Chhavi should do?
# Save evidence, secure accounts, and reach out for support while reporting.     18
# Avoid logging in to her accounts until she feels calmer.                        2
# Remove remaining files from the shared drive to prevent more leaks.             2
# Talk to friends for advice on next steps before taking action.                  1
# Name: count, dtype: int64
#
# W25-16: Ananya, 21, is the target of cyberbullying in a college WhatsApp group where personal details and insults are being spread rapidly. She feels isolated and embarrassed.\r\n\r\nWhat is the best response Ananya should do?
# Save screenshots as evidence and approach a counselor or a trusted adult for help.     23
# Block or mute key people in the group to create space.                                  3
# Stay in the group but minimize social media use for a short period.                     1
# Name: count, dtype: int64
#
# M25-7: Rohan, 22, receives a call from someone claiming to be a police officer, demanding payment.\r\n\r\nWhat is the best response Rohan should do?
# Correct: Hang up the call without giving any information, then look up and contact the official police station independently to check if the demand was real.    22
# Transfer a small part of the requested payment electronically to see what happens next, thinking he might buy time and spot whether it’s genuine or not.          4
# Call back the phone number that contacted him to ask for more details about the demand, believing he can spot a scam if they sound suspicious.                    3
# Name: count, dtype: int64
#
# W25-13: Kavya, 21, receives a call from someone pretending to be a “digital wallet helpline” asking for her OTP to resolve an issue. She feels pressured as the caller is persistent.\r\n\r\nWhat is the best response Kavya should do?
# Correct: Say no to sharing her OTP, end the call, and check with the actual wallet app’s helpline to see if there really is a problem.    24
# Tell the caller she’ll get back to them after she has time to think, and wait before making any decisions.                                 1
# Name: count, dtype: int64
#
# M60-6: Mr. Sharma, 68, finds multiple unauthorized transactions rapidly draining his pension account.\r\n\r\nWhat is the best response Mr. Sharma should do?
# Correct: Call his bank’s helpline right away to talk about what’s happening and find out how to stop further transactions.    24
# Get in touch with his son and see what advice he has before deciding what to do next.                                          1
# Name: count, dtype: int64
#
# W25-8: Nidhi, 21, receives a notification that her loan approval is complete for a loan she never applied for, and her credit report shows a large debt. What is the best response Nidhi should do?
# Correct: Contact her bank and the credit bureau as soon as possible to report the problem and ask what steps she should take.    24
# Do nothing for now, figuring it’s probably just spam and will go away by itself.                                                  2
# Call the number from the message and try to judge if it’s legitimate based on how they respond.                                   1
# Name: count, dtype: int64
#
# W60-3: Parvati, 70, suddenly loses vision in one eye while reading.\r\n\r\nWhat is the best response Parvati should do?
# Correct: Stop reading, call for help, and get to the hospital.    19
# Sprinkle eyes with water hoping it will clear the vision.          5
# Continue her activities, ignoring the issue.                       1
# Name: count, dtype: int64
#
# W25-7: Mehak, 24, receives a call from someone claiming to be from a government office, threatening legal action unless she immediately pays a "pending fine" online.\r\n\r\nWhat is the best response Mehak should do?
# Hang up, then verify the demand with official government contacts.                            21
# Pause and wait until she can talk to family, feeling too anxious to decide alone.              2
# Make a small payment now just in case, afraid she’ll get into trouble if she waits.            1
# Try bargaining on the call, reasoning that an official would allow her to settle for less.     1
# Name: count, dtype: int64
#
# W59-2: Shruti, 49, eats a snack at a wedding and within minutes feels her lips and throat swelling. She starts experiencing difficulty breathing. She remembers a doctor once mentioned a potential food allergy.\r\n\r\nWhat is the best response Shruti should do?
# Correct: Take her allergy medicine if she has it, and get someone to call for medical help right away.    17
# Call a family member to ask what she should do, before deciding on next steps.                             4
# Drink some water and wait to see if the swelling and breathing trouble settle on their own.                2
# Name: count, dtype: int64
#
# M60-2: Mr. Gupta, 67, eats sweets at a family event and his lips, face, and throat begin swelling rapidly. He finds it hard to breathe and his voice is muffled.\r\n\r\nWhat is the best response Mr. Gupta should do?
# Correct: Take his allergy medicine if he has it, and ask someone nearby to get urgent medical help instead of waiting to see if it improves.    22
# Drink some water slowly and hope it helps ease the swelling, planning to wait a bit before doing anything more.                                  3
# Name: count, dtype: int64
#
# W60-5: Shobha, 77, discovers that her medication pills look different than usual after a recent refill.What would be a sensible step for Shobha to take after noticing this change?
# Correct: Pause before taking the pills, call the pharmacy to explain what she’s noticed, and ask if there’s been any change to her prescription.    18
# Go ahead and take the medication, thinking that changes in appearance sometimes happen.                                                              3
# Check with her friends or a chat group to see if anyone else has experienced something similar, and ask what they did.                               2
# Decide not to worry about the packaging or pill color and keep using the medication as directed.                                                     2
# Name: count, dtype: int64
#
# M60-10: Mr. Singh, 66, receives an email alert asking him to urgently update his KYC details via a provided link.\r\n\r\nWhat is the best response Mr. Singh should do?
# Correct: Get in touch with his bank using the official website or stop by in person to ask if the alert is genuine before taking any action.    20
# Ignore the message for now and wait to see if the bank reaches out again with more information or reminders.                                     4
# Forward the email to family members first and ask what they think he should do about it.                                                         1
# Name: count, dtype: int64
#
# M59-5: Suresh, 48, starts sweating, shaking, and feels faint while commuting in the metro. He realizes he skipped both breakfast and lunch and is now feeling extremely weak.\r\n\r\nWhat is the best response Suresh should do?
# Correct: Sit down if possible, mention to someone nearby that he’s feeling unwell, and ask for anything sweet or sugary he can have while he waits for help.    26
# Remain standing even as he feels shaky and light-headed, telling himself he needs to push through until he reaches his destination.                              5
# Avoid making a scene, ignore his discomfort as best as he can, and wait until he gets home before taking care of his symptoms.                                   2
# Stay seated and quietly hope the weakness passes on its own, planning to grab food once he arrives at his stop.                                                  2
# Name: count, dtype: int64
#
# W25-19: Aarti, 24, receives inappropriate messages from a teaching assistant but is worried about complaining due to academic repercussions. She feels helpless but wants the behavior to stop.\r\n\r\nWhat is the best response Aarti should do?
# Correct: Keep the messages as evidence and reach out to the student support office or someone at the university who can help.    24
# Reply directly to the teaching assistant and ask them to stop sending such messages, hoping that will resolve it.                 3
# Try to avoid further conversations with the teaching assistant, hoping the situation will improve if she keeps her distance.      1
# Name: count, dtype: int64
#
# W25-15: Ruchika, 25, finds her private photographs have been leaked online and shared without her consent. She feels violated and anxious.\r\n\r\nWhat is the best response Ruchika should do?
# Save evidence and alert someone she trusts while preparing to report.                   22
# Ask trusted friends what steps she could take first.                                     2
# Try to block or report the account spreading photos but not contact anyone else yet.     1
# Consider deactivating her accounts temporarily while she figures out what to do.         1
# Name: count, dtype: int64
#
# W60-12: Malati, 70, is logged out of her email and the recovery instructions are in English, which she finds hard to understand.\r\n\r\nWhat is the best response Malati should do?
# Ask a trusted family member or neighbor for help reading the instructions.     18
# Try leaving the account unused for a while and manage without email.            4
# Call a number that appeared in a pop-up window to ask for help.                 3
# Name: count, dtype: int64
#
# W25-12: Aishwarya, 23, notices unauthorized UPI transactions on her phone after connecting to café Wi-Fi. Several payments have already gone through.\r\n\r\nWhat is the best response Aishwarya should do?
# Correct: Use her banking app to block UPI transactions right away and let her bank know what’s happened.               23
# Keep checking her bank app for more details and wait to see if any new alerts pop up before deciding on next steps.     2
# Decide to wait and call her bank later, thinking they’ll be able to sort things out when she has more time.             1
# Ask the friends she’s with what they think she should do about the unexpected payments before acting.                   1
# Name: count, dtype: int64
#
# W60-10: Anita, 70, is notified that her fixed deposit is due for renewal and receives a suspicious email link to “renew now.”\r\n\r\nWhat is the best response Anita should do?
# Correct: Check her fixed deposit status by logging into her usual banking app or visiting her bank.              16
# Use the helpline number included in the email to ask about the renewal, thinking it might be more convenient.     5
# Hold off on responding to the email, deciding to deal with the renewal at a later time.                           2
# Click the link and look over what’s being asked, planning to stop if it seems strange.                            2
# Name: count, dtype: int64
#
# M25-2: Vikram, 21, eats a dessert at a party and suddenly has swelling of his lips and tongue, struggling to breathe. People around are not sure what’s happening. He recalls having a food allergy as a child.\r\n\r\nWhat is the best response Vikram should do?
# Correct: Use allergy medication if available and call for emergency help.    23
# Drink water and wait a while.                                                 2
# Call a friend for advice first.                                               1
# Hope the swelling goes down on its own.                                       1
# Name: count, dtype: int64
#
# M60-19: Mr. Mishra, 70, is unexpectedly asked to care for his grandchildren for a week while his children travel, but feels physically and emotionally overwhelmed by the responsibility. What is the best response Mr. Mishra should do?
# Tell his family honestly that he needs help and identify specific support he’d appreciate.     19
# Ask a trusted neighbor for temporary assistance when needed.                                    2
# Agree but check in with his children if the responsibility becomes too much.                    1
# Find time for himself only when the kids are busy.                                              1
# Name: count, dtype: int64
#
# M60-12: Mr. Rao, 68, gets email alert that show sign-ins from unknown locations. He is worried about losing contact with his friends and getting scammed.\r\n\r\nWhat is the best response Mr. Rao should do?
# Change his password and set up two-factor authentication.                       20
# Wait a few hours to see if the problem resolves itself.                          2
# Ask a family member to help check what’s happening before changing anything.     1
# Name: count, dtype: int64
#
# M59-11: Deepak, 34, gets an SMS warning that his bank account will be blocked unless he “verifies” it through a suspicious link. The message appears urgent and bears his bank’s logo.\r\n\r\nWhat is the best response Deepak should do?
# Correct: Open his bank’s app or log in through his usual method to see if there are any actual alerts about his account, rather than using the link in the message.    25
# Call the phone number listed in the SMS and ask for more information, deciding how to respond based on what they say.                                                   4
# Forward the SMS to someone he trusts and see what advice or opinions they have before taking any action.                                                                4
# Name: count, dtype: int64
#
# M59-2: Praveen, 56, eats at a wedding and soon his face and tongue start swelling and he finds it hard to breathe. He knows he’s allergic to certain nuts but doesn’t recall if he had them.\r\n\r\nWhat is the best response Praveen should do?
# Correct: Use the allergy medicine he carries with him—like an antihistamine—and at the same time ask someone nearby to get emergency help.    24
# Step outside for some air and rest quietly, hoping the symptoms will start to settle down on their own.                                        4
# Quickly pull aside a close relative or friend to explain what’s happening and get their advice before acting.                                  3
# Take a few sips of water to see if the swelling eases and wait a little before deciding what else to do.                                       2
# Name: count, dtype: int64
#
# W60-4: Vimala, 63, experiences sudden confusion and inability to recognize common objects in her kitchen.\r\n\r\nWhat is the best response Vimala should do?
# Correct: Move to a safe spot, let a nearby neighbor know she’s confused, and ask for help getting checked by a doctor.    17
# Wait a while and hope her memory becomes clearer before taking any action.                                                 4
# Ignore the confusion for now and keep doing her usual tasks to see if it passes.                                           3
# Try to finish what she was doing and then take a break to rest and see if the confusion goes away.                         1
# Name: count, dtype: int64
#
# W60-6: Sushma, a 67-year-old widow, discovers that her entire pension payout for the month has suddenly disappeared from her bank account without her knowledge.\r\n\r\nWhat is the best response Sushma should do?
# Correct: Call the bank’s customer service line right away to report the missing money and freeze her account.                      19
# Wait until the next day to visit the bank in person, hoping talking face-to-face with the branch manager will help sort it out.     3
# Ask a neighbor if they’ve ever faced something similar and get their thoughts before deciding what to do.                           3
# Name: count, dtype: int64
#
# M25-4: Prateek, 22, suddenly feels intense pain and swelling after stepping on a rusty nail during a cricket game. The wound is deep and bleeding. He is worried about infection but unsure what to do.\r\nWhat is the best response Prateek should do?
# Correct: Clean the wound carefully, press to control the bleeding, cover it, and arrange to see a doctor right away.    18
# Try to wipe the wound with a cloth and keep playing, planning to properly clean and treat it after the game.             4
# Rinse the wound quickly with available water, cover it for now, and then check later if it still seems serious.          3
# Call a teammate over for their advice first and decide based on what they suggest.                                       2
# Name: count, dtype: int64
#
# M59-10: Irfan, 29, receives what looks like an official bank email urging him to click a link and update his KYC.\r\nWhat is the best response Irfan should do?
# Correct: Check his KYC status using the bank’s app or by logging in the usual way, without using the link in the email.    22
# Click the link and enter just the basics to see if it goes anywhere, then decide what to do next.                           3
# Decide to ignore the email for now and just wait to see if any further reminders come.                                      3
# Forward the message to someone in his family and ask if they’ve received anything similar before deciding.                  2
# Name: count, dtype: int64
#
# W60-8: Rani, aged 65, notices a loan has appeared on her credit report which she never took.\r\n\r\nWhat is the best response Rani should do?
# Correct: Contact her bank or credit service to ask about placing a fraud alert on her credit profile.             19
# Hold off on taking any steps until she can talk with a friend who may have handled something like this before.     3
# Assume it’s just a simple error that should get fixed automatically, so check her report again after a week.       2
# Drop by her local police station to discuss the situation and get their input before deciding what to do.          1
# Name: count, dtype: int64
#
# W25-17: Shreya, 25, discovers her roommate is spreading rumors about her in their PG hostel, leading to social exclusion. She becomes withdrawn and anxious in the common areas.\r\n\r\nWhat is the best response Shreya should do?
# Have a calm one-on-one conversation with her roommate or talk to the hostel warden.     22
# Talk through the issue first with a mutual friend, seeking suggestions.                  2
# Write a short message to her roommate expressing discomfort with the situation.          2
# Name: count, dtype: int64
