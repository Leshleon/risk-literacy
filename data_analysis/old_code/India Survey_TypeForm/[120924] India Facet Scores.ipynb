# %%
import pandas as pd
pd.set_option("display.max_columns", None)

from tqdm import tqdm
tqdm.pandas()

import numpy as np

# %%
survey = pd.read_excel("risk literacy_985 responses.xlsx", sheet_name = "643 above median")

# %%
survey
# Out:
#                                     # Please indicate your Gender.  \
# 0    wjkzxyv1zx3q7oxgmtwwjwkq24ey2n48                         Male
# 1    fbv4e1fblmp0yreyfbv4eifpzx4ax7zs                         Male
# 2    6458w9qj8sqw7ldtt56457hzeduqz2qb                       Female
# 3    9woo3kquplxhob9whhbfvhleezgy3m8l                         Male
# 4    bago2g5wtk2g5u2h0xbago2g00a6b3jx                       Female
# ..                                ...                          ...
# 638  tod55nr27ozkyci5tod5rup87g8lo9ss                         Male
# 639  phtgoyb2qh5lc4mhzq1fcphtgo8o361s                         Male
# 640  c2ba33tn344exordvkc2baixvpwi0b7s                       Female
# 641  13nxdmew77mtq97scc6r13nxduhpev0l                         Male
# 642  s5m2omt6lyzdyeb1k9cs5m2omtmv05c3                       Female
#
#     Please mark your age (in years) What is currently your highest Education?  \
# 0                           25 - 35                             Post Graduate
# ...

# %%
matchCol = ["q8_2_1", "q8_2_2", "q8_2_3", "q8_2_4", "q8_2_5", "q8_3", "q8_4", "q8_5berlin_1", 
            "q8_5london_1", "q8_5paris_1", "q8_6", "q8_7", "q9_1_1", "q9_2_1", "q9_3",
            "q10_1_1", "q10_2_1", "q10_3_1", "q10_4"]
survey[ matchCol ] = 0

# %%
survey.columns
# Out:
# Index(['#', 'Please indicate your Gender.', 'Please mark your age (in years)',
#        'What is currently your highest Education?',
#        'Please state your current occupation.',
#        'How do you describe your willingness to take financial risk in general?',
#        'Given the number of years that you have held various investments and the amount of investing you might have done, what degree of investment experience in the stock market do you have?',
#        'If an expert tries to worry or scare me, i.e. a financial advisor about my financial situation, I choose another expert.',
#        'I only buy a financial product I understand.', 'I trust doctors.',
#        'When I want to buy a bigger item like a refrigerator or an expensive item of clothing, I wait a month to see whether I still want it and only buy it then.',
#        'I always keep in mind that everything I do on the web could be used to my disadvantage.',
# ...

# %%
survey["q8_2_1"] = np.where(survey["HIV test"] == "Yes", 1, 2)
survey["q8_2_2"] = np.where(survey["Fingerprint"] == "Yes", 1, 2)
survey["q8_2_3"] = np.where(survey["DNA test"] == "Yes", 1, 2)
survey["q8_2_4"] = np.where(survey["Cancer screening test"] == "Yes", 1, 2)
survey["q8_2_5"] = np.where(survey["Professional horoscope"] == "Yes", 1, 2)

survey["q8_3"] = np.where(survey["A study estimates that eating 100g chocolate everyday increases the risk of obesity by 20%.  Which of the following statements is true?"] == "The lower the quality of the study, the more likely that future studies will change the risk estimate.", 1,
                          np.where(survey["A study estimates that eating 100g chocolate everyday increases the risk of obesity by 20%.  Which of the following statements is true?"] == "The higher the quality of the study, the more likely that future studies will change the risk estimate.", 2,
                                  np.where(survey["A study estimates that eating 100g chocolate everyday increases the risk of obesity by 20%.  Which of the following statements is true?"] == "Irrespective of the quality of the study, future studies will not change the risk estimate.", 3,
                                          np.where(survey["A study estimates that eating 100g chocolate everyday increases the risk of obesity by 20%.  Which of the following statements is true?"] == "Irrespective of the quality of the study, future studies will change the risk estimate substantially anyway.", 4,0
                                                  )
                                          )
                                  )
                         )


survey["q8_4"] = np.where(survey["There is an official prediction that the national stock market will grow 2% annually over the next 5 years.  This means that…"] == "the growth rate will be 0.4% on average each year", 1,
                          np.where(survey["There is an official prediction that the national stock market will grow 2% annually over the next 5 years.  This means that…"] == "the growth rate over five years will be exactly 2%", 2,
                                  np.where(survey["There is an official prediction that the national stock market will grow 2% annually over the next 5 years.  This means that…"] == "the growth rate over five years will be between 1% and 3%", 3,
                                          np.where(survey["There is an official prediction that the national stock market will grow 2% annually over the next 5 years.  This means that…"] == "it is not possible to predict the growth rate with certainty.", 4,0
                                                  )
                                          )
                                  )
                         )

# %%
survey["HIV test"].value_counts()
# Out:
# HIV test
# Yes    436
# No     207
# Name: count, dtype: int64

# %%
survey["q8_2_1"].value_counts()
# Out:
# q8_2_1
# 1    436
# 2    207
# Name: count, dtype: int64

# %%
survey["q8_5berlin_1"] = np.where(survey["*Mumbai * A = 9 out of 10000   *OR   * B = 1 out of 1000"] == "A", 1, 2)
survey["q8_5london_1"] = np.where(survey["*Bengaluru * A = 0.7%   *OR  * B = 0.099%"] == "A", 1, 2)
survey["q8_5paris_1"] = np.where(survey["*Kolkata * A = 0.61%   *OR   * B = 6 out of 10000"] == "A", 1, 2)

survey["q8_6"] = np.where(survey["Imagine you are told that a new medication increases the number of people who recover from a disease from 2 out of 1,000 to 4 out of 1,000.  This implies:"] == "The medication increases recovery by 100%", 1,
                          np.where(survey["Imagine you are told that a new medication increases the number of people who recover from a disease from 2 out of 1,000 to 4 out of 1,000.  This implies:"] == "The medication increases recovery by 50%", 2,
                                   np.where(survey["Imagine you are told that a new medication increases the number of people who recover from a disease from 2 out of 1,000 to 4 out of 1,000.  This implies:"] == "The medication increases recovery by 2%", 3,
                                            np.where(survey["Imagine you are told that a new medication increases the number of people who recover from a disease from 2 out of 1,000 to 4 out of 1,000.  This implies:"] == "None of the above is implied.", 4, 0
                                                    )
                                           )
                                  )
                         )

survey["q8_7"] = np.where(survey["A new policy intervention increases the number of people who are employed by 20%. This statistic implies that the intervention increases the number of people who are employed from:"] == "5 in 100 people prior to the intervention to 6 out of 100 people after the intervention", 1,
                          np.where(survey["A new policy intervention increases the number of people who are employed by 20%. This statistic implies that the intervention increases the number of people who are employed from:"] == "100 in 10,000 people prior to the intervention to 120 out of 10,000 people after the intervention", 2,
                                   np.where(survey["A new policy intervention increases the number of people who are employed by 20%. This statistic implies that the intervention increases the number of people who are employed from:"] == "70 in 100 people prior to the intervention to 90 out of 100 people after the intervention", 3,
                                            np.where(survey["A new policy intervention increases the number of people who are employed by 20%. This statistic implies that the intervention increases the number of people who are employed from:"] == "it is not possible to determine which of the answers is correct given the information provided", 4, 0
                                                    )
                                           )
                                  )
                         )


survey["q9_1_1"] = survey["Approximately what percentage (%) of people who die from cancer die from colon cancer, breast cancer, and prostate cancer taken together?"].copy()
survey["q9_2_1"] = survey["The following figure shows the number of men and women among a group of smartphone users. The total number of circles is 100. \n\nHow many more men than women are there among the 100 people using a smartphone?"].copy()

survey["q9_3"] = np.where(survey["In a magazine you see two advertisements, one on page 5 and another on page 12. Each is for a different drug for treating heart disease, and each includes a graph showing the effectiveness of the drug compared to a placebo (sugar pill).\n\nCompared to the placebo, which treatment leads to a larger decrease in the percentage of patients who die?"] == "Crosicol", 1,
                          np.where(survey["In a magazine you see two advertisements, one on page 5 and another on page 12. Each is for a different drug for treating heart disease, and each includes a graph showing the effectiveness of the drug compared to a placebo (sugar pill).\n\nCompared to the placebo, which treatment leads to a larger decrease in the percentage of patients who die?"] == "Hertinol", 2,
                                   np.where(survey["In a magazine you see two advertisements, one on page 5 and another on page 12. Each is for a different drug for treating heart disease, and each includes a graph showing the effectiveness of the drug compared to a placebo (sugar pill).\n\nCompared to the placebo, which treatment leads to a larger decrease in the percentage of patients who die?"] == "They are equal", 3,
                                            np.where(survey["In a magazine you see two advertisements, one on page 5 and another on page 12. Each is for a different drug for treating heart disease, and each includes a graph showing the effectiveness of the drug compared to a placebo (sugar pill).\n\nCompared to the placebo, which treatment leads to a larger decrease in the percentage of patients who die?"] == "Can’t say", 4, 0
                                                    )
                                           )
                                  )
                         )

# %%
survey["In a magazine you see two advertisements, one on page 5 and another on page 12. Each is for a different drug for treating heart disease, and each includes a graph showing the effectiveness of the drug compared to a placebo (sugar pill).\n\nCompared to the placebo, which treatment leads to a larger decrease in the percentage of patients who die?"].value_counts()
# Out:
# In a magazine you see two advertisements, one on page 5 and another on page 12. Each is for a different drug for treating heart disease, and each includes a graph showing the effectiveness of the drug compared to a placebo (sugar pill).\n\nCompared to the placebo, which treatment leads to a larger decrease in the percentage of patients who die?
# They are equal    212
# Hertinol          207
# Crosicol          160
# Can’t say          64
# Name: count, dtype: int64

# %%
survey["q9_3"].value_counts()
# Out:
# q9_3
# 3    212
# 2    207
# 1    160
# 4     64
# Name: count, dtype: int64

# %%
survey["q10_1_1"] = survey["Imagine that we flip a fair coin 1,000 times. What is your best guess about how many times the coin will come up heads in 1,000 flips? \n\n\_\_\_\_\_\_ times out of 1,000."].copy()
survey["q10_2_1"] = survey["In the Bingo Lottery, the chance of winning a $10 prize is 1%. What is your best guess about how many people will win a $10 prize if 1,000 people each buy a single ticket for Bingo Lottery?\n\n\_\_\_\_\_\_ person(s) out of 1,000."].copy()
survey["q10_3_1"] = survey["In a sweepstakes, the chance of winning a car is 1 in 1,000. What percentage of tickets for the sweepstakes wins a car?\n\n\_\_\_\_\_ % of tickets"].copy()

survey["q10_4"] = np.where(survey["About 10 out of 1,000 children develop Down syndrome. In a Down syndrome test, 9 out of these 10 children with Down syndrome tested positive. Out of the 990 children without Down syndrome 50 nevertheless tested positive. Among those women with a positive test result concerning their child how many actually have a child with Down syndrome? [Select one response only]"] == "9 out of 59", 1,
                          np.where(survey["About 10 out of 1,000 children develop Down syndrome. In a Down syndrome test, 9 out of these 10 children with Down syndrome tested positive. Out of the 990 children without Down syndrome 50 nevertheless tested positive. Among those women with a positive test result concerning their child how many actually have a child with Down syndrome? [Select one response only]"] == "9 out of 10", 2,
                                   np.where(survey["About 10 out of 1,000 children develop Down syndrome. In a Down syndrome test, 9 out of these 10 children with Down syndrome tested positive. Out of the 990 children without Down syndrome 50 nevertheless tested positive. Among those women with a positive test result concerning their child how many actually have a child with Down syndrome? [Select one response only]"] == "59 out of 1000", 3,
                                            np.where(survey["About 10 out of 1,000 children develop Down syndrome. In a Down syndrome test, 9 out of these 10 children with Down syndrome tested positive. Out of the 990 children without Down syndrome 50 nevertheless tested positive. Among those women with a positive test result concerning their child how many actually have a child with Down syndrome? [Select one response only]"] == "59 out of 100", 4, 0
                                                    )
                                           )
                                  )
                         )

# %%
survey["About 10 out of 1,000 children develop Down syndrome. In a Down syndrome test, 9 out of these 10 children with Down syndrome tested positive. Out of the 990 children without Down syndrome 50 nevertheless tested positive. Among those women with a positive test result concerning their child how many actually have a child with Down syndrome? [Select one response only]"].value_counts()
# Out:
# About 10 out of 1,000 children develop Down syndrome. In a Down syndrome test, 9 out of these 10 children with Down syndrome tested positive. Out of the 990 children without Down syndrome 50 nevertheless tested positive. Among those women with a positive test result concerning their child how many actually have a child with Down syndrome? [Select one response only]
# 59 out of 1000    226
# 9 out of 10       187
# 9 out of 59       129
# 59 out of 100     101
# Name: count, dtype: int64

# %%
survey["#"].value_counts()
# Out:
# #
# wjkzxyv1zx3q7oxgmtwwjwkq24ey2n48    1
# wscpvnwx7f6f63202bdhy5wscpv0lerg    1
# e06b0w4eikmre06b3d23ldldmwei23d2    1
# s9n52bxxl3vwsqpzdjis9n52g0hf2rag    1
# bab5zhi8fo63qarwbab5hjvd3fmiy3tz    1
#                                    ..
# uvso72c2fuaeuh96uvso72ekxywavnvj    1
# 1ohqvf2m3cyq2ic1ptxkji91ohqvf2m6    1
# 8bkbabwbsdxut8bkba8zmczwciojohj6    1
# n5tap3d3v5102n5tay187lv3mwzs3sjy    1
# s5m2omt6lyzdyeb1k9cs5m2omtmv05c3    1
# Name: count, Length: 643, dtype: int64

# %%
scoreColumns = ["certainty1", "certainty2", "certainty3", "certainty4", "certainty5", "uncertainty1", "uncertainty2", "numeracy1", "numeracy2", "numeracy3", "numeracy4", "numeracy5", "graph1", "graph2", "graph3", "riskcalculation1", "riskcalculation2", "riskcalculation3", "riskcalculation4"]
survey[scoreColumns] = 0

# %%
# Assigning scores

def scoring1(surveyFacet):
    surveyFacet.loc[ surveyFacet["q8_2_1"] == 2, "certainty1"] = 1
    surveyFacet.loc[ surveyFacet["q8_2_2"] == 2, "certainty2"] = 1
    surveyFacet.loc[ surveyFacet["q8_2_3"] == 2, "certainty3"] = 1
    surveyFacet.loc[ surveyFacet["q8_2_4"] == 2, "certainty4"] = 1
    surveyFacet.loc[ surveyFacet["q8_2_5"] == 2, "certainty5"] = 1

    surveyFacet.loc[ surveyFacet["q8_3"] == 1, "uncertainty1"] = 1
    surveyFacet.loc[ surveyFacet["q8_4"] == 4, "uncertainty2"] = 1

    surveyFacet.loc[ surveyFacet["q8_5berlin_1"] == 2, "numeracy1"] = 1
    surveyFacet.loc[ surveyFacet["q8_5london_1"] == 1, "numeracy2"] = 1
    surveyFacet.loc[ surveyFacet["q8_5paris_1"] == 1, "numeracy3"] = 1
    surveyFacet.loc[ surveyFacet["q8_6"] == 1, "numeracy4"] = 1
    surveyFacet.loc[ surveyFacet["q8_7"] == 4, "numeracy5"] = 1

    surveyFacet.loc[ surveyFacet["q9_1_1"] == 25, "graph1"] = 1
    surveyFacet.loc[ surveyFacet["q9_2_1"] == 20, "graph2"] = 1
    surveyFacet.loc[ surveyFacet["q9_3"] == 3, "graph3"] = 1

    surveyFacet.loc[ surveyFacet["q10_1_1"] == 500, "riskcalculation1"] = 1
    surveyFacet.loc[ surveyFacet["q10_2_1"] == 10, "riskcalculation2"] = 1
    surveyFacet.loc[ (surveyFacet["q10_3_1"] == 0.1) | (surveyFacet["q10_3_1"] == ".1") | (surveyFacet["q10_3_1"] == ",1") , "riskcalculation3"] = 1
    surveyFacet.loc[ surveyFacet["q10_4"] == 1, "riskcalculation4"] = 1

    # Assigning total scores
    # surveyFacet["Certainty score_5"] = surveyFacet["certainty1"] + surveyFacet["certainty2"] + surveyFacet["certainty3"] + surveyFacet["certainty4"] + surveyFacet["certainty5"]
    #surveyFacet["Uncertainty score_5"] = surveyFacet["uncertainty1"] + surveyFacet["uncertainty2"]

    #surveyFacet["Number Comprehension score_5"] = surveyFacet["numeracy1"] + surveyFacet["numeracy2"] + surveyFacet["numeracy3"] + surveyFacet["numeracy4"] + surveyFacet["numeracy5"]
    #surveyFacet["Graph Comprehension score_5"] = surveyFacet["graph1"] + surveyFacet["graph2"] + surveyFacet["graph3"]

    #surveyFacet["Calculation score_4"] = surveyFacet["riskcalculation1"] + surveyFacet["riskcalculation2"] + surveyFacet["riskcalculation3"] + surveyFacet["riskcalculation4"]

    #surveyFacet["Total Score_19"] = surveyFacet["Certainty score_5"] + surveyFacet["Uncertainty score_5"] + surveyFacet["Number Comprehension score_5"] + surveyFacet["Graph Comprehension score_5"] + surveyFacet["Calculation score_4"]

    return surveyFacet

# %%
surveyFacet = survey.groupby(["#"]).progress_apply(scoring1)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 643/643 [00:03<00:00, 177.57it/s]

# %%
surveyFacet
# Out:
#                                                                      #  \
# #
# 00dn8csjzlekx6gzhrcv00dn8csj32tz 547  00dn8csjzlekx6gzhrcv00dn8csj32tz
# 00ujdxbfoya0donu8r00ujcjdkojc99x 428  00ujdxbfoya0donu8r00ujcjdkojc99x
# 01ro2iftnum5v4cn01r03c75aa24emhq 528  01ro2iftnum5v4cn01r03c75aa24emhq
# 022xoawhrghfhv4a1g022xmz7hb0m41f 442  022xoawhrghfhv4a1g022xmz7hb0m41f
# 02pxtdbyibecqqfvwlw02pxwfbane9zd 558  02pxtdbyibecqqfvwlw02pxwfbane9zd
# ...                                                                ...
# zeoufbqlngfunzzeoymhtj2sp5cw6lur 396  zeoufbqlngfunzzeoymhtj2sp5cw6lur
# zfemo30rg0ekva18x1kjwzfemo2wpg2p 185  zfemo30rg0ekva18x1kjwzfemo2wpg2p
# znqvw4t38br3072znqvwvjsgb6wvj7nt 305  znqvw4t38br3072znqvwvjsgb6wvj7nt
# zstpq23h1x3ilab8s8vsrbkw8t4zstpq 306  zstpq23h1x3ilab8s8vsrbkw8t4zstpq
# ztfdlcbiyo1xco3ztfdl4ozqpte2q3m9 95   ztfdlcbiyo1xco3ztfdl4ozqpte2q3m9
#
#                                      Please indicate your Gender.  \
# #
# ...

# %%
surveyFacet.to_csv("India_riskliteracy_dataset_above median_2024_new.csv")
