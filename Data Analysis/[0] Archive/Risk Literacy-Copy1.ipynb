# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
# Data Frame 1 or df1 is an aggregate data on all questions and facet total scores and over all total score vs each response

df1 = pd.read_excel('Survey Data.xlsx', sheet_name = 'Risk Facet scores')
df1
# Out:
#      responseid  q8_2_1  q8_2_2  q8_2_3  q8_2_4  q8_2_5  q8_3  q8_4  \
# 0          6873       1       1       1       1       2     2     4
# 1         14129       2       2       2       1       2     4     3
# 2          5861       1       1       1       2       2     4     4
# 3         13364       2       1       2       1       1     4     1
# 4         14112       2       2       2       2       2     2     3
# ..          ...     ...     ...     ...     ...     ...   ...   ...
# 647       14135       1       1       2       1       2     4     3
# 648       14155       2       2       2       2       2     4     4
# 649       14274       1       1       1       2       2     3     4
# 650       14448       2       2       2       2       2     2     2
# 651       15717       1       2       1       1       2     4     4
#
#      q8_5berlin_1  q8_5london_1  ...  Number Comprehension score_5  \
# 0               1             1  ...                             2
# ...

# %%
# Data Frame 2 or df2 is an aggregate data on facet total scores and over all total score vs each response

df2 = pd.read_excel('Survey Data.xlsx', sheet_name = 'Wealth and Income')
df2
# Out:
#      responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0          6873            6          NaN                  1
# 1         14129            1       3000.0                  4
# 2          5861            2          0.0                  2
# 3         13364            5     105000.0                  2
# 4         14112            3      34865.0                  5
# ..          ...          ...          ...                ...
# 647       14135            1        500.0                  2
# 648       14155            6          NaN                  5
# 649       14274            2          NaN                  2
# 650       14448            3          NaN                  5
# 651       15717            1          NaN                  2
#
#      Uncertainty score_2  Number Comprehension score_5  \
# 0                      1                             2
# 1                      0                             3
# 2                      1                             3
# ...

# %%
# The following graph represents frequency of each data point on "Total Score_19" or the total score out of 19 across the sample.

df1['Total Score_19'].plot(kind = 'hist', xticks = np.arange(0, 20, step=1), xlabel = 'Total Score_19', title = 'Frequency of Scores' )
# Out:
# <Axes: title={'center': 'Frequency of Scores'}, xlabel='Total Score_19', ylabel='Frequency'>

# %%
# Data Frame 3 or df3 is an aggregate data on facet total scores and over all total score, along with wealth and income data vs each response. This data set is also sorted by wealth with all responses '7' removed (7 refers to "prefer not say" option).

df3 = df2.sort_values(by = 'Q12. Wealth')
df3 = df3.reset_index(drop = True)
df3.drop(df3[df3['Q12. Wealth'] == 7].index, inplace = True)
df3
# Out:
#      responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0         15717            1          NaN                  2
# 1           219            1      80000.0                  5
# 2           845            1          NaN                  1
# 3          8599            1       2500.0                  3
# 4         12715            1        200.0                  3
# ..          ...          ...          ...                ...
# 572        7893            6       1000.0                  1
# 573        6296            6          NaN                  5
# 574        5806            6          NaN                  2
# 575        1086            6          NaN                  3
# 576         679            6          NaN                  2
#
#      Uncertainty score_2  Number Comprehension score_5  \
# 0                      1                             3
# 1                      1                             4
# 2                      0                             2
# ...

# %%
# This graph is basically a line plot of the Total score_19 across all the unique responses which are ordered by wealth

df3.plot(use_index = 'True' , kind = 'line', y = ['Total Score_19'], title = 'Total responses line plot sorted by wealth',xlabel = 'Unique responses', ylabel = 'Total Score_19')
# Out:
# <Axes: title={'center': 'Total responses line plot sorted by wealth'}, xlabel='Unique responses', ylabel='Total Score_19'>

# %%
# Mean scores for each facet for Dataframe 3

df3.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_%','Uncertainty score_%','Number Comprehension score_%','Graph Comprehension score_%','Calculation score_%','Total Score_%']).mean(axis = 0).plot(kind = 'bar', title = 'Mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Mean of scores for above data set'}>

# %%
# Normalised mean scores for each facet for Dataframe 3

(df3.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0)).plot(kind = 'bar', title = 'Normalised mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Normalised mean of scores for above data set'}>

# %%
# Dataframe 4 representing Top 25%ile responses by wealth

df4 = df3.iloc[int(3*652/4)+1:652]
df4 = df4.reset_index(drop = True)
df4
# Out:
#     responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0        13314            5      35000.0                  3
# 1        10822            5       6666.0                  3
# 2           30            5     130000.0                  2
# 3         2310            5          NaN                  2
# 4         5574            5      75000.0                  2
# ..         ...          ...          ...                ...
# 82        7893            6       1000.0                  1
# 83        6296            6          NaN                  5
# 84        5806            6          NaN                  2
# 85        1086            6          NaN                  3
# 86         679            6          NaN                  2
#
#     Uncertainty score_2  Number Comprehension score_5  \
# 0                     0                             1
# 1                     0                             3
# 2                     1                             3
# ...

# %%
# Line plot representing the Total score_19 for the top 25%ile of wealth responses

df4.plot(use_index = 'True' , kind = 'line', y = ['Total Score_19'], title = 'Top 25%ile line plot sorted by wealth',xlabel = 'Unique responses', ylabel = 'Total Score_19')
# Out:
# <Axes: title={'center': 'Top 25%ile line plot sorted by wealth'}, xlabel='Unique responses', ylabel='Total Score_19'>

# %%
# Mean scores for each facet for Dataframe 4

df4.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_%','Uncertainty score_%','Number Comprehension score_%','Graph Comprehension score_%','Calculation score_%','Total Score_%']).mean(axis = 0).plot(kind = 'bar', title = 'Mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Mean of scores for above data set'}>

# %%
# Normalised mean scores for each facet for Dataframe 4

df4.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0).plot(kind = 'bar', title = 'Normalised mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Normalised mean of scores for above data set'}>

# %%
# Dataframe 5 representing Top 25%ile responses by wealth

df5 = df3.iloc[0:int(652/4)]
df5 = df5.reset_index(drop = True)
df5
# Out:
#      responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0         15717            1          NaN                  2
# 1           219            1      80000.0                  5
# 2           845            1          NaN                  1
# 3          8599            1       2500.0                  3
# 4         12715            1        200.0                  3
# ..          ...          ...          ...                ...
# 158        1769            2     425000.0                  3
# 159        1796            2       3000.0                  4
# 160        5903            2          NaN                  5
# 161        2053            2       6000.0                  5
# 162        2272            2          NaN                  2
#
#      Uncertainty score_2  Number Comprehension score_5  \
# 0                      1                             3
# 1                      1                             4
# 2                      0                             2
# ...

# %%
# Line plot representing the Total score_19 for the Bottom 25%ile of wealth responses

df5.plot(use_index = 'True' , kind = 'line', y = ['Total Score_19'], title = 'Bottom 25%ile line plot sorted by wealth',xlabel = 'Unique responses', ylabel = 'Total Score_19')
# Out:
# <Axes: title={'center': 'Bottom 25%ile line plot sorted by wealth'}, xlabel='Unique responses', ylabel='Total Score_19'>

# %%
# Mean scores for each facet for Dataframe 5

df5.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_%','Uncertainty score_%','Number Comprehension score_%','Graph Comprehension score_%','Calculation score_%','Total Score_%']).mean(axis = 0).plot(kind = 'bar', title = 'Mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Mean of scores for above data set'}>

# %%
# Normalised mean scores for each facet for Dataframe 5

df5.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0).plot(kind = 'bar', title = 'Normalised mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Normalised mean of scores for above data set'}>

# %%
# Top 25%ile vs Bottom 25%ile Normalised mean scores for each facet for Dataframe 4

df = pd.concat[df4.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0), df4.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0)].plot(kind = 'bar', title = 'Top 25%ile vs Bottom 25%ile Normalised mean of scores for above data set')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Top 25%ile vs Bottom 25%ile Normalised mean scores for each facet for Dataframe 4
# ----> 3 df = pd.concat[df4.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0), df4.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0)].plot(kind = 'bar', title = 'Top 25%ile vs Bottom 25%ile Normalised mean of scores for above data set')
#
# TypeError: 'function' object is not subscriptable

# %%
#Here, We sort values by Income from the main dataframe, i.e., df2, and drop those rows with non existant values to create Dataframe 7

df6 = df2.sort_values(by = 'Q14. Income')
df6 = df6.reset_index(drop = True)
df7 = df6.dropna(axis = 0, subset = 'Q14. Income')
df7
# Out:
#      responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0          2305            4          0.0                  1
# 1          5760            3          0.0                  1
# 2          5463            6          0.0                  2
# 3           796            2          0.0                  5
# 4          2578            3          0.0                  1
# ..          ...          ...          ...                ...
# 375          15            6    1250000.0                  2
# 376         970            6    1350000.0                  2
# 377        5592            7    1500000.0                  3
# 378       10809            6    1650000.0                  3
# 379         278            6    3500000.0                  5
#
#      Uncertainty score_2  Number Comprehension score_5  \
# 0                      0                             3
# 1                      0                             3
# 2                      1                             4
# ...

# %%
# This graph is basically a line plot of the Total score_19 across all the unique responses which are ordered by wealth

df7.plot(use_index = 'True' , kind = 'line', y = ['Total Score_19'], title = 'Total responses line plot sorted by Income',xlabel = 'Unique responses', ylabel = 'Total Score_19')
# Out:
# <Axes: title={'center': 'Total responses line plot sorted by Income'}, xlabel='Unique responses', ylabel='Total Score_19'>

# %%
# Mean scores for each facet for Dataframe 7

df7.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_%','Uncertainty score_%','Number Comprehension score_%','Graph Comprehension score_%','Calculation score_%','Total Score_%']).mean(axis = 0).plot(kind = 'bar', title = 'Mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Mean of scores for above data set'}>

# %%
# Mean scores for each facet for Dataframe 7

df7.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0).plot(kind = 'bar', title = 'Normalised mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Normalised mean of scores for above data set'}>

# %%
# Dataframe 8 representing Top 25%ile responses by Income

df8 = df7.iloc[int(3*380/4 + 1):380]
df8
# Out:
#      responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 286        1315            2     200000.0                  1
# 287         490            1     200000.0                  1
# 288       13403            5     200000.0                  3
# 289       13350            6     200000.0                  2
# 290        1681            6     200000.0                  5
# ..          ...          ...          ...                ...
# 375          15            6    1250000.0                  2
# 376         970            6    1350000.0                  2
# 377        5592            7    1500000.0                  3
# 378       10809            6    1650000.0                  3
# 379         278            6    3500000.0                  5
#
#      Uncertainty score_2  Number Comprehension score_5  \
# 286                    2                             4
# 287                    1                             4
# 288                    1                             3
# ...

# %%
# Line plot representing the Total score_19 for the Top 25%ile of income responses

df8.plot(use_index = 'True' , kind = 'line', y = ['Total Score_19'], title = 'Top 25%ile line plot sorted by Income',xlabel = 'Unique responses', ylabel = 'Total Score_19')
# Out:
# <Axes: title={'center': 'Top 25%ile line plot sorted by Income'}, xlabel='Unique responses', ylabel='Total Score_19'>

# %%
# Mean scores for each facet for Dataframe 8

df8.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_%','Uncertainty score_%','Number Comprehension score_%','Graph Comprehension score_%','Calculation score_%','Total Score_%']).mean(axis = 0).plot(kind = 'bar', title = 'Mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Mean of scores for above data set'}>

# %%
# Mean scores for each facet for Dataframe 8

df8.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0).plot(kind = 'bar', title = 'Normalised mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Normalised mean of scores for above data set'}>

# %%
# Dataframe 9 representing Bottom 25%ile responses by Income

df9 = df7.iloc[0:int(380/4)]
df9
# Out:
#     responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0         2305            4          0.0                  1
# 1         5760            3          0.0                  1
# 2         5463            6          0.0                  2
# 3          796            2          0.0                  5
# 4         2578            3          0.0                  1
# ..         ...          ...          ...                ...
# 90        1803            3       4000.0                  3
# 91        5831            4       4000.0                  2
# 92         909            1       4500.0                  1
# 93        6661            2       4500.0                  5
# 94        5729            1       5000.0                  2
#
#     Uncertainty score_2  Number Comprehension score_5  \
# 0                     0                             3
# 1                     0                             3
# 2                     1                             4
# ...

# %%
# Line plot representing the Total score_19 for the Bottom 25%ile of income responses

df9.plot(use_index = 'True' , kind = 'line', y = ['Total Score_19'], title = 'Bottom 25%ile line plot sorted by Income',xlabel = 'Unique responses', ylabel = 'Total Score_19')
# Out:
# <Axes: title={'center': 'Bottom 25%ile line plot sorted by Income'}, xlabel='Unique responses', ylabel='Total Score_19'>

# %%
# Mean scores for each facet for Dataframe 9

df9.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_%','Uncertainty score_%','Number Comprehension score_%','Graph Comprehension score_%','Calculation score_%','Total Score_%']).mean(axis = 0).plot(kind = 'bar', title = 'Mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Mean of scores for above data set'}>

# %%
# Mean scores for each facet for Dataframe 9

df9.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).mean(axis = 0).plot(kind = 'bar', title = 'Normalised mean of scores for above data set')
# Out:
# <Axes: title={'center': 'Normalised mean of scores for above data set'}>

# %%
# I tried stacking the different facets on top of each other vs all the responses for some apparent visualization, to no avail. I cannot make much out of this.

df3.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income','Certainty score_5','Uncertainty score_2','Number Comprehension score_5','Graph Comprehension score_3','Calculation score_4','Total Score_19']).plot(kind = 'bar', stacked = True, title = 'Total responses stacked bar plot sorted by wealth',xlabel = 'Unique responses', ylabel = 'Score')
# Out:
# <Axes: title={'center': 'Total responses stacked bar plot sorted by wealth'}, xlabel='Unique responses', ylabel='Score'>

# %%
# WIP WIP WIP I am trying to figure out stacked graph without creating a new excel data for ease of use for future data. 
# While, its not hard to take the mean of each quartile and stack them, I want to be able to do it a bit more intuitively 
# and efficiently with the already loaded data. I will do this in no time.

df3.drop(axis = 1, labels = ['responseid', 'Q12. Wealth', 'Q14. Income']).mean().plot(kind = 'bar', stacked = True)
# Out:
# <Axes: >

# %%
# Dataframe 10 is a copy of df3 but with an added column for easy indexing using column name.

df10 = df3.copy()
df10.insert(loc = 0,column = "Response Number", value = pd.Series(range(1,int(df3.shape[0]+1))), allow_duplicates = 'False')
df10
# Out:
#      Response Number  responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0                  1       15717            1          NaN                  2
# 1                  2         219            1      80000.0                  5
# 2                  3         845            1          NaN                  1
# 3                  4        8599            1       2500.0                  3
# 4                  5       12715            1        200.0                  3
# ..               ...         ...          ...          ...                ...
# 572              573        7893            6       1000.0                  1
# 573              574        6296            6          NaN                  5
# 574              575        5806            6          NaN                  2
# 575              576        1086            6          NaN                  3
# 576              577         679            6          NaN                  2
#
# ...

# %%
# This is the plot of all responses against their total scores SORTED by WEALTH with a linear regression line

sns.regplot(x = 'Response Number', y='Total Score_19', data=df10, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Total Score_19'>

# %%
# For Calculation score_4

sns.regplot(x = 'Response Number', y='Calculation score_4', data=df10, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Calculation score_4'>

# %%
# For Graph Comprehension score_3 

sns.regplot(x = 'Response Number', y='Graph Comprehension score_3', data=df10, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Graph Comprehension score_3'>

# %%
# For Number Comprehension score_5

sns.regplot(x = 'Response Number', y='Number Comprehension score_5', data=df10, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Number Comprehension score_5'>

# %%
# For Uncertainty score_2 

sns.regplot(x = 'Response Number', y='Uncertainty score_2', data=df10, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Uncertainty score_2'>

# %%
# For Certainty score_2 

sns.regplot(x = 'Response Number', y='Certainty score_5', data=df10, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Certainty score_5'>

# %%
# Dataframe 11 is a copy of df7 but with an added column for easy indexing using column name.

df11 = df7.copy()
df11.insert(loc = 0,column = "Response Number", value = pd.Series(range(1,int(df7.shape[0]+1))), allow_duplicates = 'False')
df11
# Out:
#      Response Number  responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0                  1        2305            4          0.0                  1
# 1                  2        5760            3          0.0                  1
# 2                  3        5463            6          0.0                  2
# 3                  4         796            2          0.0                  5
# 4                  5        2578            3          0.0                  1
# ..               ...         ...          ...          ...                ...
# 375              376          15            6    1250000.0                  2
# 376              377         970            6    1350000.0                  2
# 377              378        5592            7    1500000.0                  3
# 378              379       10809            6    1650000.0                  3
# 379              380         278            6    3500000.0                  5
#
# ...

# %%
# This is the plot of all responses against their total scores SORTED by WEALTH with a linear regression line

sns.regplot(x = 'Response Number', y='Total Score_19', data=df11, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Total Score_19'>

# %%
# For Calculation score_4

sns.regplot(x = 'Response Number', y='Calculation score_4', data=df11, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Calculation score_4'>

# %%
# For Graph Comprehension score_3 

sns.regplot(x = 'Response Number', y='Graph Comprehension score_3', data=df11, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Graph Comprehension score_3'>

# %%
# For Number Comprehension score_5

sns.regplot(x = 'Response Number', y='Number Comprehension score_5', data=df11, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Number Comprehension score_5'>

# %%
# For Uncertainty score_2 

sns.regplot(x = 'Response Number', y='Uncertainty score_2', data=df11, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Uncertainty score_2'>

# %%
# For Certainty score_2 

sns.regplot(x = 'Response Number', y='Certainty score_5', data=df11, fit_reg=True)
# Out:
# <Axes: xlabel='Response Number', ylabel='Certainty score_5'>

# %%
# Violine Plot for Total Score_19 for each entry under Wealth.

sns.violinplot( data = df10, x = 'Q12. Wealth', y = 'Total Score_19')
# Out:
# <Axes: xlabel='Q12. Wealth', ylabel='Total Score_19'>

# %%
# Violine Plot for Calculation score_4 for each entry under Wealth.

sns.violinplot( data = df10, x = 'Q12. Wealth', y = 'Calculation score_4')
# Out:
# <Axes: xlabel='Q12. Wealth', ylabel='Calculation score_4'>

# %%
# Violine Plot for Graph Comprehension score_3 for each entry under Wealth.

sns.violinplot( data = df10, x = 'Q12. Wealth', y = 'Graph Comprehension score_3')
# Out:
# <Axes: xlabel='Q12. Wealth', ylabel='Graph Comprehension score_3'>

# %%
# Violine Plot for Number Comprehension score_5 for each entry under Wealth.

sns.violinplot( data = df10, x = 'Q12. Wealth', y = 'Number Comprehension score_5')
# Out:
# <Axes: xlabel='Q12. Wealth', ylabel='Number Comprehension score_5'>

# %%
# Violine Plot for Number Comprehension score_5 for each entry under Wealth.

sns.violinplot( data = df10, x = 'Q12. Wealth', y = 'Number Comprehension score_5')
# Out:
# <Axes: xlabel='Q12. Wealth', ylabel='Number Comprehension score_5'>

# %%
# Violine Plot for Certainty score_5 for each entry under Wealth.

sns.violinplot( data = df10, x = 'Q12. Wealth', y = 'Certainty score_5')
# Out:
# <Axes: xlabel='Q12. Wealth', ylabel='Certainty score_5'>

# %%
# WIP WIP WIP Assigning Quartile dummy variable

df12 = df10.copy()
df12.insert(loc = len(df12.columns), column = "Quartile Number", value = 4, allow_duplicates = 'False')

df12
# Out:
#      Response Number  responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0                  1       15717            1          NaN                  2
# 1                  2         219            1      80000.0                  5
# 2                  3         845            1          NaN                  1
# 3                  4        8599            1       2500.0                  3
# 4                  5       12715            1        200.0                  3
# ..               ...         ...          ...          ...                ...
# 572              573        7893            6       1000.0                  1
# 573              574        6296            6          NaN                  5
# 574              575        5806            6          NaN                  2
# 575              576        1086            6          NaN                  3
# 576              577         679            6          NaN                  2
#
# ...

# %%
df11['Quartile Number'] = pd.qcut(df11["Q14. Income"],q = 4, labels = False ) + 1

# %%
df11.pivot(columns= "Quartile Number",values='Total Score_19').describe()
# Out:
# Quartile Number           1          2          3          4
# count            122.000000  74.000000  89.000000  95.000000
# mean               9.877049  10.851351  11.483146  12.242105
# std                3.269134   3.147874   3.424883   3.542195
# min                2.000000   3.000000   3.000000   2.000000
# 25%                8.000000   9.000000   9.000000  10.000000
# 50%               10.000000  11.000000  12.000000  12.000000
# 75%               12.000000  13.000000  14.000000  15.000000
# max               17.000000  18.000000  18.000000  18.000000

# %%
df11.pivot(columns= "Quartile Number",values='Total Score_19').describe().loc['mean']
# Out:
# Quartile Number
# 1     9.877049
# 2    10.851351
# 3    11.483146
# 4    12.242105
# Name: mean, dtype: float64

# %%
df11
# Out:
#      Response Number  responseid  Q12. Wealth  Q14. Income  Certainty score_5  \
# 0                  1        2305            4          0.0                  1
# 1                  2        5760            3          0.0                  1
# 2                  3        5463            6          0.0                  2
# 3                  4         796            2          0.0                  5
# 4                  5        2578            3          0.0                  1
# ..               ...         ...          ...          ...                ...
# 375              376          15            6    1250000.0                  2
# 376              377         970            6    1350000.0                  2
# 377              378        5592            7    1500000.0                  3
# 378              379       10809            6    1650000.0                  3
# 379              380         278            6    3500000.0                  5
#
# ...

# %%
sns.violinplot( data = df11, x= 'Quartile Number', y='Total Score_19')
# Out:
# <Axes: xlabel='Quartile Number', ylabel='Total Score_19'>

# %%
sns.regplot( x = "Quartile Number", y = 'Total Score_19', data = df11)
# Out:
# <Axes: xlabel='Quartile Number', ylabel='Total Score_19'>
